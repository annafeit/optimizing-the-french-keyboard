# %%
from objectives import * 
from read_input import *
from plotting import *
from reformulation_input import *
from evaluate_reformualtion_solution import * 
from optimize import *

# %matplotlib inline

PYTHONIOENCODING="utf-8"

w_p, w_a, w_f, w_e =  [0.25,0.25,0.25,0.25]
corpus_weights = {'formal':0.5, 'twitter':0.3, 'code':0.2}
# Out:
# C:\Users\feita1\Python_Anaconda\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
scenario = "scenarioMAX"
char_set = "setCAPS"
set_scenario_files(scenario, char_set)
#create_reformulation_input(w_p, w_a, w_f, w_e, corpus_weights, scenario+char_set+"_even",
                           #quadratic=1)

mapping = solve_the_keyboard_Problem(w_p, w_a, w_f, w_e, corpus_weights, 
                                     quadratic=0, capitalization_constraints=1, name=scenario+char_set+"_even")
#model = optimize_reformulation("reformulation\\reformulation_scenario3_ass.lp")
#w_p, w_a, w_f, w_e = [0.25,0.25,0.25,0.25]
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# set objective
# Adding capitalization constraints
# à, À, not in character set
# â, Â, not in character set
# ç, Ç, not in character set
# é, É, not in character set
# è, È, not in character set
# ë, Ë, not in character set
# ê, Ê, not in character set
# ï, Ï, not in character set
# î, Î, not in character set
# ô, Ô, not in character set
# ù, Ù, not in character set
# û, Û, not in character set
# ü, Ü, not in character set
# ÿ, Ÿ, not in character set
# set constraints
# Warning: variable name ":_to_B00" has a colon
# Warning: constraint name ":_mapped_once" has a colon
# Warning: to let Gurobi read it back, use rlp format
# optimizing with linear terms only...
# Optimize a model with 1540 rows, 15609 columns and 33098 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [1e-10, 1e-01]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+00]
# Found incumbent soln at node 0 objective 0.45531340307
# Found heuristic solution: objective 0.455313
# Presolve removed 1300 rows and 1990 columns
# Presolve time: 0.13s
# Presolved: 240 rows, 13619 columns, 27828 nonzeros
# Variable types: 0 continuous, 13619 integer (13619 binary)
#
# Root relaxation: objective 1.707160e-01, 877 iterations, 0.07 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.17072    0   44    0.45531    0.17072  62.5%     -    0s
# Found incumbent soln at node 0 objective 0.173309630899
# H    0     0                       0.1733096    0.17072  1.50%     -    0s
# Found incumbent soln at node 0 objective 0.172711878261
# H    0     0                       0.1727119    0.17072  1.16%     -    0s
# Found incumbent soln at node 0 objective 0.172058845748
# *    0     0               0       0.1720588    0.17206  0.00%     -    0s
#
# Cutting planes:
#   Clique: 4
#   Mod-K: 4
#
# Explored 0 nodes (898 simplex iterations) in 0.78 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.720588457479e-01, best bound 1.720588457479e-01, gap 0.0%
# done
# Performance: 0.366
# Association: 0.051
# Familiarity: 0.088
# Ergonomics: 0.182
# ! to B10
# " to E02
# # to E06
# $ to C12_Shift
# % to C11_Shift
# & to E00
# ' to E04
# ( to E05
# ) to E10
# * to C11
# + to E11
# , to B07
# ,d to B06_Alt_Shift
# - to E07
# -d to E09_Alt_Shift
# . to B08
# .d to B09_Alt_Shift
# / to B09_Shift
# /d to E00_Alt
# : to B09
# ; to B08_Shift
# < to B00
# = to D12
# > to B00_Shift
# ? to B07_Shift
# @ to D01_Alt
# [ to D06_Alt
# \ to C08_Alt
# ] to D10_Alt
# ^ to E09_Alt
# ^d to D11
# _ to E08
# _d to E12_Shift
# { to C04_Alt
# | to B07_Alt
# } to E12
# ~ to E02_Alt
# ~d to B06_Alt
# ¡ to E10_Alt
# ¢ to B04_Alt_Shift
# £ to E11_Shift
# ¤ to B08_Alt_Shift
# ¥ to D06_Alt_Shift
# § to C11_Alt
# ¨d to C10_Alt
# © to B03_Alt_Shift
# ª to D01_Alt_Shift
# « to E09
# ® to D04_Alt_Shift
# ° to B08_Alt
# °d to D12_Shift
# ± to D12_Alt
# ´d to C01_Alt
# · to B10_Alt
# ¸d to B04_Alt
# º to C09_Alt_Shift
# » to B10_Shift
# ¼ to C10_Alt_Shift
# ½ to C12_Alt_Shift
# ¾ to D10_Alt_Shift
# ¿ to E06_Alt
# Æ to E01_Alt_Shift
# Ð to C03_Alt_Shift
# × to D11_Alt
# Þ to D05_Alt_Shift
# ß to C02_Alt
# à to E01
# æ to E01_Alt
# ç to B03_Alt
# è to D04_Alt
# é to E03
# ð to C03_Alt
# ÷ to B07_Alt_Shift
# ù to D07_Alt
# þ to D05_Alt
# İ to E08_Alt_Shift
# ı to E08_Alt
# Ĳ to D08_Alt_Shift
# ĳ to D08_Alt
# Ŋ to B05_Alt_Shift
# ŋ to B05_Alt
# Œ to D09_Alt_Shift
# œ to D09_Alt
# ſ to B02_Alt_Shift
# Ə to E12_Alt_Shift
# Ʒ to C07_Alt_Shift
# ə to E12_Alt
# ʒ to C07_Alt
# ˇd to E03_Alt
# ˉd to D02_Alt
# ˋd to E07_Alt
# ˘d to E04_Alt
# ˙d to C12_Alt
# ˛d to C01_Alt_Shift
# ˝d to D12_Alt_Shift
# ˵d to E00_Alt_Shift
# ̑d to D11_Alt_Shift
# θ2 to B00_Alt
# ẞ to C02_Alt_Shift
# ‑ to E00_Shift
# – to C05_Alt
# — to B09_Alt
# ‘ to D11_Shift
# ’ to C12
# ‚ to B10_Alt_Shift
# “ to C06_Alt
# ” to B01_Alt
# „ to C05_Alt_Shift
# † to E05_Alt
# ‡ to B00_Alt_Shift
# … to C09_Alt
# ‰ to E07_Alt_Shift
# ‹ to D03_Alt_Shift
# › to B02_Alt
# ₩ to B01_Alt_Shift
# √ to E04_Alt_Shift
# ∞ to C08_Alt_Shift
# ≃ to D02_Alt_Shift
# ≠ to C04_Alt_Shift
# ≤ to E11_Alt
# ≥ to E10_Alt_Shift
# Obj: 0.172059
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# linear Association: 0.0510
# quadratic Association: 0.0000

# %%
path = "mappings/solution_3_even.mst"
plot_mapping(mapping, plotname=path+".png", w_p=w_p, w_a=w_a, w_f=w_f, w_e=w_e,  
             corpus_weights=corpus_weights, quadratic=1)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# linear Association: 4.9747
# quadratic Association: 0.0000

# %%
new_mapping = swap_and_plot(mapping, u"à", u":",corpus_weights, w_p, w_a, w_f, w_e,  plot=True)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.

# %%
azerty,\
    characters,\
    keyslots,\
    letters,\
    p_single, p_bigram,\
    performance,\
    similarity_c_c, similarity_c_l,\
    distance_level_0, distance_level_1,\
    ergonomics\
     = get_all_input_values(corpus_weights)
        
linear_cost, x_P, x_A, x_F, x_E = get_linear_costs(w_p, w_a, w_f, w_e, 
                           azerty,\
                           characters,\
                           keyslots,\
                           letters,\
                           p_single, p_bigram,\
                           performance,\
                           similarity_c_c, similarity_c_l,\
                           distance_level_0, distance_level_1,\
                           ergonomics)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
