# %%
from objectives import * 
from read_input import *
from plotting import *
from reformulation_input import *
from evaluate_reformualtion_solution import * 
from optimize import *

# %matplotlib inline

PYTHONIOENCODING="utf-8"

w_p, w_a, w_f, w_e =  [1.0, 0.0,0.0,0.0]
corpus_weights = {'formal':0.5, 'twitter':0.3, 'code':0.2}
# Out:
# C:\Users\feita1\Python_Anaconda\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
scenario = "scenarioMAX"
char_set = "setCAPS"
set_scenario_files(scenario, char_set)
#create_reformulation_input(w_p, w_a, w_f, w_e, corpus_weights, scenario+char_set+"_even",
                           #quadratic=1)

mapping = solve_the_keyboard_Problem(w_p, w_a, w_f, w_e, corpus_weights, 
                                     quadratic=0, capitalization_constraints=1, name=scenario+char_set+"_even", minimize=False)
#model = optimize_reformulation("reformulation\\reformulation_scenario3_ass.lp")
#w_p, w_a, w_f, w_e = [0.25,0.25,0.25,0.25]
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# set objective
# Adding capitalization constraints
# à, À, not in character set
# â, Â, not in character set
# ç, Ç, not in character set
# é, É, not in character set
# è, È, not in character set
# ë, Ë, not in character set
# ê, Ê, not in character set
# ï, Ï, not in character set
# î, Î, not in character set
# ô, Ô, not in character set
# ù, Ù, not in character set
# û, Û, not in character set
# ü, Ü, not in character set
# ÿ, Ÿ, not in character set
# set constraints
# Warning: variable name ":_to_B00" has a colon
# Warning: constraint name ":_mapped_once" has a colon
# Warning: to let Gurobi read it back, use rlp format
# optimizing with linear terms only...
# Optimize a model with 1540 rows, 15609 columns and 33098 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [3e-07, 2e-01]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+00]
# Found incumbent soln at node 0 objective 0.361744398295
# Found heuristic solution: objective 0.361744
# Presolve removed 1300 rows and 1990 columns
# Presolve time: 0.08s
# Presolved: 240 rows, 13619 columns, 27828 nonzeros
# Variable types: 0 continuous, 13619 integer (13619 binary)
#
# Root relaxation: objective 9.642069e-01, 1048 iterations, 0.05 seconds
# Found incumbent soln at node 0 objective 0.964206876163
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9642069    0.96421  0.00%     -    0s
#
# Explored 0 nodes (1048 simplex iterations) in 0.31 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.642068761626e-01, best bound 9.642068761626e-01, gap 0.0%
# done
# Performance: 0.964
# Association: 0.508
# Familiarity: 0.542
# Ergonomics: 0.623
# ! to C07_Alt_Shift
# " to B06_Alt_Shift
# # to D11_Alt_Shift
# $ to D10_Alt_Shift
# % to D09_Alt_Shift
# & to E12_Alt_Shift
# ' to E06_Alt_Shift
# ( to E01_Alt_Shift
# ) to B09_Alt_Shift
# * to C06_Alt_Shift
# + to D04_Alt_Shift
# , to E08_Alt_Shift
# ,d to C03_Alt
# - to C04_Alt_Shift
# -d to C11_Alt
# . to C02_Alt_Shift
# .d to D01_Alt
# / to D08_Alt_Shift
# /d to E02
# : to B07_Alt_Shift
# ; to E04_Alt_Shift
# < to C11_Alt_Shift
# = to B05_Alt_Shift
# > to E00_Alt_Shift
# ? to D07_Alt_Shift
# @ to E11_Alt_Shift
# [ to C10_Alt_Shift
# \ to C04_Alt
# ] to E03_Alt_Shift
# ^ to C09_Alt_Shift
# ^d to D05_Alt_Shift
# _ to B04_Alt_Shift
# _d to B04_Alt
# { to B10_Alt_Shift
# | to E09_Alt_Shift
# } to C08_Alt_Shift
# ~ to B10_Alt
# ~d to E00_Shift
# ¡ to B00_Alt
# ¢ to B03_Alt
# £ to E08_Alt
# ¤ to E01_Alt
# ¥ to E09_Alt
# § to E03_Alt
# ¨d to C03_Alt_Shift
# © to D02_Alt_Shift
# ª to D10_Alt
# « to E05_Alt_Shift
# ® to B02_Alt
# ° to E10_Alt_Shift
# °d to E02_Alt
# ± to E05_Alt
# ´d to B03_Alt_Shift
# · to E11_Alt
# ¸d to D03_Alt_Shift
# º to D06_Alt
# » to D01_Alt_Shift
# ¼ to E05
# ½ to E12_Shift
# ¾ to B06_Alt
# ¿ to C05_Alt
# Æ to B00_Shift
# Ð to B09_Shift
# × to E12_Alt
# Þ to D11_Shift
# ß to D12
# à to B02_Alt_Shift
# æ to B00
# ç to E02_Alt_Shift
# è to B08_Alt_Shift
# é to E07_Alt_Shift
# ð to B09
# ÷ to E07_Alt
# ù to C01_Alt_Shift
# þ to D11
# İ to E11_Shift
# ı to E11
# Ĳ to B08_Shift
# ĳ to B08
# Ŋ to B07_Shift
# ŋ to B07
# Œ to B01_Alt_Shift
# œ to B01_Alt
# ſ to D02_Alt
# Ə to C12_Shift
# Ʒ to B10_Shift
# ə to C12
# ʒ to B10
# ˇd to B05_Alt
# ˉd to D12_Alt
# ˋd to D12_Alt_Shift
# ˘d to E00_Alt
# ˙d to E06_Alt
# ˛d to C11_Shift
# ˝d to E10_Alt
# ˵d to E12
# ̑d to B07_Alt
# θ2 to C12_Alt
# ẞ to D12_Shift
# ‑ to D04_Alt
# – to B00_Alt_Shift
# — to C05_Alt_Shift
# ‘ to C02_Alt
# ’ to D06_Alt_Shift
# ‚ to C09_Alt
# “ to D07_Alt
# ” to D11_Alt
# „ to B08_Alt
# † to D08_Alt
# ‡ to C10_Alt
# … to C12_Alt_Shift
# ‰ to B09_Alt
# ‹ to E01
# › to C08_Alt
# ₩ to C07_Alt
# √ to E06
# ∞ to D09_Alt
# ≃ to D05_Alt
# ≠ to C11
# ≤ to E00
# ≥ to C06_Alt
# Obj: 0.964207
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# linear Association: 0.5078
# quadratic Association: 0.0000

# %%
path = "mappings/solution_3_even.mst"
plot_mapping(mapping, plotname=path+".png", w_p=w_p, w_a=w_a, w_f=w_f, w_e=w_e,  
             corpus_weights=corpus_weights, quadratic=1)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# linear Association: 4.9747
# quadratic Association: 0.0000

# %%
new_mapping = swap_and_plot(mapping, u"à", u":",corpus_weights, w_p, w_a, w_f, w_e,  plot=True)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.

# %%
azerty,\
    characters,\
    keyslots,\
    letters,\
    p_single, p_bigram,\
    performance,\
    similarity_c_c, similarity_c_l,\
    distance_level_0, distance_level_1,\
    ergonomics\
     = get_all_input_values(corpus_weights)
        
linear_cost, x_P, x_A, x_F, x_E = get_linear_costs(w_p, w_a, w_f, w_e, 
                           azerty,\
                           characters,\
                           keyslots,\
                           letters,\
                           p_single, p_bigram,\
                           performance,\
                           similarity_c_c, similarity_c_l,\
                           distance_level_0, distance_level_1,\
                           ergonomics)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
