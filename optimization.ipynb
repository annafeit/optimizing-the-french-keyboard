# %%
from objectives import * 
from read_input import *
from plotting import *
from reformulation_input import *
from evaluate_reformualtion_solution import * 
from optimize import *

# %matplotlib inline

PYTHONIOENCODING="utf-8"

w_p, w_a, w_f, w_e =  [0.25,0.25,0.25,0.25]
corpus_weights = {'formal':0.8, 'twitter':0.1, 'code':0.1}
scenario = "scenarioMAX"
char_set = "setCOMBCAPS"
set_scenario_files(scenario, char_set)
# Out:
# C:\Users\feita1\Python_Anaconda\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
create_reformulation_input(w_p, w_a, w_f, w_e, corpus_weights, scenario+char_set+"_even",
                           quadratic=0)

#mapping = solve_the_keyboard_Problem(w_p, w_a, w_f, w_e, corpus_weights, 
#                                     quadratic=0, capitalization_constraints=1, name=scenario+char_set+"_perf", minimize=True)
#model = optimize_reformulation("reformulation\\reformulation_scenario3_ass.lp")
#w_p, w_a, w_f, w_e = [0.25,0.25,0.25,0.25]
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# Getting linear cost
# ========= Normalize Performance =========
# Adding capitalization constraints
# ===> Minimum: 0.00818
# ===> Maximum: 0.03763
# ========= Normalize Association =========
# Adding capitalization constraints
# ===> Minimum: 0.04345
# ===> Maximum: 1.21418
# ========= Normalize Familiarity =========
# Adding capitalization constraints
# ===> Minimum: 0.00000
# ===> Maximum: 0.04946
# ========= Normalize Ergonomics =========
# Adding capitalization constraints
# ===> Minimum: 0.00684
# ===> Maximum: 0.05288
# Getting quadratic cost
# Done.

# %%
filename = "scenarioMAXsetCOMBCAPS_even.lp"
mapping = optimize_reformulation("reformulation/input/"+filename, capitalization=1)
# Out:
# SETTING: nodefileStart = 0.5
# optimizing...
# Optimize a model with 18099 rows, 33282 columns and 66548 nonzeros
# Coefficient statistics:
#   Matrix range    [1e-04, 4e+01]
#   Objective range [1e+00, 1e+00]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [9e-05, 2e+01]
# Presolve removed 17842 rows and 17911 columns
# Presolve time: 0.20s
# Presolved: 257 rows, 15371 columns, 31863 nonzeros
# Variable types: 0 continuous, 15371 integer (15371 binary)
# Found incumbent soln at node 0 objective 264.450689
# Found heuristic solution: objective 264.4506890
#
# Root relaxation: objective 2.631529e+02, 1455 iterations, 0.09 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  263.15293    0   28  264.45069  263.15293  0.49%     -    0s
# Found incumbent soln at node 0 objective 263.353149
# H    0     0                     263.3531490  263.15293  0.08%     -    0s
# Found incumbent soln at node 0 objective 263.353148
# H    0     0                     263.3531480  263.15293  0.08%     -    1s
# Found incumbent soln at node 0 objective 263.296014
# *    0     0               0     263.2960140  263.29601  0.00%     -    1s
#
# Cutting planes:
#   Clique: 4
#   Mod-K: 1
#
# Explored 0 nodes (1587 simplex iterations) in 1.38 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.632960140000e+02, best bound 2.632960140000e+02, gap 0.0%
# done
# Optimal objective: 263.296

# %%
path = "mappings/scenarioMAXsetCOMBCAPS_even/scenarioMAXsetCOMBCAPS_even_263.2960.mst"
plot_mapping(path, plotname=path+".png", w_p=w_p, w_a=w_a, w_f=w_f, w_e=w_e,  
             corpus_weights=corpus_weights, quadratic=0)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# Getting linear cost
# linear Association: 6.2414
# quadratic Association: 0.0000

# %%
new_mapping = swap_and_plot(mapping, u"à", u":",corpus_weights, w_p, w_a, w_f, w_e,  plot=True)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.

# %%
azerty,\
    characters,\
    keyslots,\
    letters,\
    p_single, p_bigram,\
    performance,\
    similarity_c_c, similarity_c_l,\
    distance_level_0, distance_level_1,\
    ergonomics\
     = get_all_input_values(corpus_weights)
        
linear_cost, x_P, x_A, x_F, x_E = get_linear_costs(w_p, w_a, w_f, w_e, 
                           azerty,\
                           characters,\
                           keyslots,\
                           letters,\
                           p_single, p_bigram,\
                           performance,\
                           similarity_c_c, similarity_c_l,\
                           distance_level_0, distance_level_1,\
                           ergonomics)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
