# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from objectives import *

# %matplotlib inline 

set_scenario_files("scenario3")

# %%
corpus_weights = {"formal":0.8, "twitter":0.1, "code":0.1}
azerty,\
    characters,\
    keyslots,\
    letters,\
    p_single, p_bigram,\
    performance,\
    similarity_c_c, similarity_c_l,\
    distance_level_0, distance_level_1,\
    ergonomics\
     = get_all_input_values(corpus_weights)
        
linear_cost, x_P, x_A, x_F, x_E = get_linear_costs(0.25, 0.25, 0.25, 0.25, 
                               azerty,\
                               characters,\
                               keyslots,\
                               letters,\
                               p_single, p_bigram,\
                               performance,\
                               similarity_c_c, similarity_c_l,\
                               distance_level_0, distance_level_1,\
                               ergonomics)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.

# %%
fig, axes = plt.subplots(1,2)
fig.set_size_inches(8,4)
axes[0].hist(performance.values());
axes[1].hist(x_P.values());
axes[0].set_title("Performance (key-key)")
axes[1].set_title("Cost (character-key)")

# %%
fig, axes = plt.subplots(1,2)
fig.set_size_inches(8,4)
axes[0].hist(similarity_c_l.values());
axes[1].hist(x_A.values());
axes[0].set_title("Association c-l (character-letter)")
axes[1].set_title("Cost (character-key)")

# %%
fig, axes = plt.subplots(1,2)
fig.set_size_inches(8,4)
axes[0].hist(distance_level_1.values());
axes[1].hist(x_F.values());
axes[0].set_title("Familiarty (key-key)")
axes[1].set_title("Cost (character-key)")

# %%
fig, axes = plt.subplots(1,2)
fig.set_size_inches(8,4)
axes[0].hist(ergonomics.values());
axes[1].hist(x_E.values());
axes[0].set_title("Ergonomics (key-key)")
axes[1].set_title("Cost (character-key)")

# %%
# Out:
# 12178
