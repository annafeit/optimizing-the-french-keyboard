# %%
import pandas as pd
from pandas.tools.plotting import parallel_coordinates
import numpy as np
import seaborn as sns
from plotting import *
from read_input import *
# %matplotlib inline
PYTHONIOENCODING="utf-8"

sns.set_style("white")
sns.set(font_scale=1.5)
# Out:
# C:\Users\feita1\Python_Anaconda\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# # Inspect Mapping
# This code is used to inspect why a certain character is mapped to a certain position.
#
# Define:
# - path to mapping
# - corresponding scenario name
# - corresponding weights
# - corresponding corpus weights

# %%
scenario = "scenario3a"
mapping = "mappings/solution_3a_even.mst"
corpus_weights = {"formal":0.5, "twitter":0.3, "code":0.2}
w_p, w_a, w_f, w_e = [0.25,0.25,0.25,0.25]

set_scenario_files(scenario)

# %% [markdown]
# ### Plot mapping
# Use this function to plot any mapping

# %%
#read in mapping to dictionary of character to key
plot_mapping(mapping, w_p=w_p, w_a=w_a, w_f=w_f, w_e=w_e, corpus_weights=corpus_weights)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# linear Association: 0.3843
# quadratic Association: 0.6719

# %% [markdown]
# ### Swap characters
# This function can be used to swap any two characters in the mapping and plot the result with the new objectives.
#
# <code> mapping </code> can be the path to the mapping or the actual dictionary

# %%
#todo swap more characters and compute score in comparison to optimal mapping
new_mapping = swap_and_plot(mapping, "?", "!",corpus_weights, w_p, w_a, w_f, w_e,  plot=True)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.

# %% [markdown]
# ### Inspect character position
# Swaps the position of the given character with all other characters. Plots show how the scores would change for any swap

# %%
character_swap_with_all(mapping, u".", corpus_weights, w_p, w_a, w_f, w_e)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# Swapping characters
# C:\Users\feita1\Python_Anaconda\lib\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
from optimize import * 
optimum_mapping = local_optimization(mapping, w_p=w_p, w_a=w_a, w_f=w_f, w_e=w_e, corpus_weights=corpus_weights)
plot_mapping(optimum_mapping, w_p=w_p, w_a=w_a, w_f=w_f, w_e=w_e, corpus_weights=corpus_weights)
