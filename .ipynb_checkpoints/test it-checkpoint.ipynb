# %%
# -*- coding: utf-8 -*-
from optimize import *
from test_model import *
from plotting import *
from read_input import *
import codecs

# %matplotlib inline
PYTHONIOENCODING="utf-8"

def characters(_character_file):
    with codecs.open(_character_file, encoding='utf-8') as f:
        characters_file = f.read().splitlines()
    characters = [correct_diacritic(c.strip()) for c in characters_file]      
    return characters
# Out:
# C:\Users\feita1\Python_Anaconda\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
letter_file = "input/resources/frequency_letters_mathieu.txt"
bigram_file = "input/resources/frequency_bigrams_mathieu.txt"
letters = get_letters()


scenario="_scenario1"
all_chars = characters('input/characters'+scenario+'.txt')
all_chars = letters + all_chars
output_letters = "input/resources/frequency_letters"+scenario+'.txt'
output_bigrams = "input/resources/frequency_bigrams"+scenario+'.txt'
derive_probabilities_from_raw_values(letter_file, bigram_file, all_chars, output_bigrams, output_letters)

scenario="_scenario2"
all_chars = characters('input/characters'+scenario+'.txt')
all_chars = letters + all_chars
output_letters = "input/resources/frequency_letters"+scenario+'.txt'
output_bigrams = "input/resources/frequency_bigrams"+scenario+'.txt'
derive_probabilities_from_raw_values(letter_file, bigram_file, all_chars, output_bigrams, output_letters)

scenario="_scenario3"
all_chars = characters('input/characters'+scenario+'.txt')
all_chars = letters + all_chars
output_letters = "input/resources/frequency_letters"+scenario+'.txt'
output_bigrams = "input/resources/frequency_bigrams"+scenario+'.txt'
derive_probabilities_from_raw_values(letter_file, bigram_file, all_chars, output_bigrams, output_letters)
# Out:
# 5000 of 304793
# 10000 of 304793
# 15000 of 304793
# 20000 of 304793
# 25000 of 304793
# 30000 of 304793
# 35000 of 304793
# 40000 of 304793
# 45000 of 304793
# 50000 of 304793
# 55000 of 304793
# 60000 of 304793
# 65000 of 304793
# 70000 of 304793
# 75000 of 304793
# 80000 of 304793
# 85000 of 304793
# 90000 of 304793
# 95000 of 304793
# 100000 of 304793
# 105000 of 304793
# 110000 of 304793
# 115000 of 304793
# 120000 of 304793
# 125000 of 304793
# 130000 of 304793
# 135000 of 304793
# 140000 of 304793
# 145000 of 304793
# 150000 of 304793
# 155000 of 304793
# 160000 of 304793
# 165000 of 304793
# 170000 of 304793
# 175000 of 304793
# 180000 of 304793
# 185000 of 304793
# 190000 of 304793
# 195000 of 304793
# 200000 of 304793
# 205000 of 304793
# 210000 of 304793
# 215000 of 304793
# 220000 of 304793
# 225000 of 304793
# 230000 of 304793
# 235000 of 304793
# 240000 of 304793
# 245000 of 304793
# 250000 of 304793
# 255000 of 304793
# 260000 of 304793
# 265000 of 304793
# 270000 of 304793
# 275000 of 304793
# 280000 of 304793
# 285000 of 304793
# 290000 of 304793
# 295000 of 304793
# 300000 of 304793
# No frequency for (¼, °), assigning minimum
# No frequency for (ψ, ‡), assigning minimum
# No frequency for (η, ù), assigning minimum
# No frequency for (¢, #), assigning minimum
# No frequency for (», Υ), assigning minimum
# No frequency for (ẞ, ˋd), assigning minimum
# No frequency for (‑, À), assigning minimum
# No frequency for (μ, Ĳ), assigning minimum
# No frequency for (‑, Ω), assigning minimum
# No frequency for (Μ, w), assigning minimum
# No frequency for (Θ, ˙d), assigning minimum
# No frequency for (Ε, ω), assigning minimum
# No frequency for (r, Ρ), assigning minimum
# No frequency for (/d, Γ), assigning minimum
# No frequency for (≥, ¨d), assigning minimum
# No frequency for (p, ^d), assigning minimum
# No frequency for (Δ, π), assigning minimum
# No frequency for (c, /d), assigning minimum
# No frequency for (y, Λ), assigning minimum
# No frequency for (υ, w), assigning minimum
# No frequency for (¤, É), assigning minimum
# No frequency for (r, Ð), assigning minimum
# No frequency for (”, º), assigning minimum
# No frequency for (g, ν), assigning minimum
# No frequency for (›, j), assigning minimum
# No frequency for (Δ, .d), assigning minimum
# No frequency for (Ρ, ˙d), assigning minimum
# No frequency for (<, .d), assigning minimum
# No frequency for (Ζ, ρ), assigning minimum
# No frequency for (ξ, +), assigning minimum
# No frequency for (ˇd, Ŋ), assigning minimum
# No frequency for (h, Π), assigning minimum
# No frequency for (İ, &), assigning minimum
# No frequency for (ψ, ŋ), assigning minimum
# No frequency for (‑, º), assigning minimum
# No frequency for (±, Γ), assigning minimum
# No frequency for (γ, †), assigning minimum
# No frequency for (^d, ‹), assigning minimum
# No frequency for (^d, ≤), assigning minimum
# No frequency for (p, Ǝ), assigning minimum
# No frequency for (+, ª), assigning minimum
# No frequency for (Ξ, #), assigning minimum
# No frequency for (Λ, ≠), assigning minimum
# No frequency for (Ξ, ʒ), assigning minimum
# No frequency for (ß, Μ), assigning minimum
# No frequency for (ʒ, ¤), assigning minimum
# No frequency for (Ʒ, β), assigning minimum
# No frequency for (Η, υ), assigning minimum
# No frequency for (Β, ≃), assigning minimum
# No frequency for (Ξ, Æ), assigning minimum
# No frequency for (Υ, r), assigning minimum
# No frequency for (˵d, Θ), assigning minimum
# No frequency for (ı, -d), assigning minimum
# No frequency for (Ρ, _), assigning minimum
# No frequency for (˝d, ˇd), assigning minimum
# No frequency for (-d, l), assigning minimum
# No frequency for (Ρ, s), assigning minimum
# No frequency for (Υ, º), assigning minimum
# No frequency for (Ε, ¡), assigning minimum
# No frequency for (ο, ß), assigning minimum
# No frequency for (α, ‘), assigning minimum
# No frequency for (~d, †), assigning minimum
# No frequency for (Ǝ, -), assigning minimum
# No frequency for (¼, ^d), assigning minimum
# No frequency for (Σ, ψ), assigning minimum
# No frequency for (Θ, „), assigning minimum
# No frequency for (‚, Ǝ), assigning minimum
# No frequency for (”, ζ), assigning minimum
# No frequency for (¸d, ι), assigning minimum
# No frequency for (Ʒ, j), assigning minimum
# No frequency for (ß, ù), assigning minimum
# No frequency for (~d, Β), assigning minimum
# No frequency for (¢, Τ), assigning minimum
# No frequency for (À, ù), assigning minimum
# No frequency for (Β, ù), assigning minimum
# No frequency for (˝d, Θ), assigning minimum
# No frequency for (Ψ, e), assigning minimum
# No frequency for (|, Ǝ), assigning minimum
# No frequency for (δ, œ), assigning minimum
# No frequency for (n, Ι), assigning minimum
# No frequency for (Ζ, °), assigning minimum
# No frequency for (Ç, ~d), assigning minimum
# No frequency for (˝d, _), assigning minimum
# No frequency for (©, œ), assigning minimum
# No frequency for (¸d, Η), assigning minimum
# No frequency for (~d, <), assigning minimum
# No frequency for (q, ₩), assigning minimum
# No frequency for (˵d, ﻿æ), assigning minimum
# No frequency for («, ÷), assigning minimum
# No frequency for (﻿æ, ’), assigning minimum
# No frequency for (>, τ), assigning minimum
# No frequency for (k, Ĳ), assigning minimum
# No frequency for (ù, ˇd), assigning minimum
# No frequency for (Τ, ‹), assigning minimum
# No frequency for (˝d, >), assigning minimum
# No frequency for (₩, ‰), assigning minimum
# No frequency for (̑d, ≤), assigning minimum
# No frequency for (‑, Β), assigning minimum
# No frequency for (ν, ˝d), assigning minimum
# No frequency for (¢, ©), assigning minimum
# No frequency for (ˉd, ≠), assigning minimum
# No frequency for (Φ, “), assigning minimum
# No frequency for (Λ, ˵d), assigning minimum
# No frequency for (Ζ, ˇd), assigning minimum
# No frequency for (ð, Ç), assigning minimum
# No frequency for (ª, j), assigning minimum
# No frequency for (ψ, Σ), assigning minimum
# No frequency for (Π, ˝d), assigning minimum
# No frequency for (“, Ǝ), assigning minimum
# No frequency for (Τ, k), assigning minimum
# No frequency for (Þ, Γ), assigning minimum
# No frequency for (f, Β), assigning minimum
# No frequency for (”, μ), assigning minimum
# No frequency for (ˋd, Β), assigning minimum
# No frequency for (j, †), assigning minimum
# No frequency for (Π, ẞ), assigning minimum
# No frequency for (θ, <), assigning minimum
# No frequency for (ẞ, γ), assigning minimum
# No frequency for (≥, Ω), assigning minimum
# No frequency for (£, ≠), assigning minimum
# No frequency for (§, ο), assigning minimum
# No frequency for (-d, ·), assigning minimum
# No frequency for (Ρ, »), assigning minimum
# No frequency for (¼, Ζ), assigning minimum
# No frequency for (È, Ð), assigning minimum
# No frequency for (¨d, Β), assigning minimum
# No frequency for (Δ, Æ), assigning minimum
# No frequency for (¼, Τ), assigning minimum
# No frequency for (_, π), assigning minimum
# No frequency for (.d, †), assigning minimum
# No frequency for (†, Δ), assigning minimum
# No frequency for (ξ, ð), assigning minimum
# No frequency for (Ĳ, ‘), assigning minimum
# No frequency for (‡, +), assigning minimum
# No frequency for (ι, Ʒ), assigning minimum
# No frequency for (_, ‹), assigning minimum
# No frequency for (θ2, Ε), assigning minimum
# No frequency for (Ν, ĳ), assigning minimum
# No frequency for (v, ˝d), assigning minimum
# No frequency for (ˋd, .d), assigning minimum
# No frequency for (±, é), assigning minimum
# No frequency for (ç, ß), assigning minimum
# No frequency for (ω, Ψ), assigning minimum
# No frequency for (†, χ), assigning minimum
# No frequency for (‚, τ), assigning minimum
# No frequency for (˛d, ˵d), assigning minimum
# No frequency for («, þ), assigning minimum
# No frequency for (É, ι), assigning minimum
# No frequency for (¾, ¥), assigning minimum
# No frequency for (Ʒ, ð), assigning minimum
# No frequency for ([, η), assigning minimum
# No frequency for (e, Ð), assigning minimum
# No frequency for (¢, Ω), assigning minimum
# No frequency for (≥, ”), assigning minimum
# No frequency for (ð, ˛d), assigning minimum
# No frequency for (̑d, x), assigning minimum
# No frequency for (¼, f), assigning minimum
# No frequency for (φ, ù), assigning minimum
# No frequency for (Ĳ, ≥), assigning minimum
# No frequency for (˛d, -d), assigning minimum
# No frequency for (˵d, ſ), assigning minimum
# No frequency for (^d, Μ), assigning minimum
# No frequency for (Ο, È), assigning minimum
# No frequency for („, ù), assigning minimum
# No frequency for (Τ, {), assigning minimum
# No frequency for (ˋd, ˉd), assigning minimum
# No frequency for (≃, İ), assigning minimum
# No frequency for (±, \), assigning minimum
# No frequency for (ſ, ₩), assigning minimum
# No frequency for (i, Ε), assigning minimum
# No frequency for (¾, l), assigning minimum
# No frequency for (œ, ß), assigning minimum
# No frequency for (¥, π), assigning minimum
# No frequency for (y, ξ), assigning minimum
# No frequency for (×, ¢), assigning minimum
# No frequency for (Ε, ÷), assigning minimum
# No frequency for (Ε, ¢), assigning minimum
# No frequency for (þ, ˘d), assigning minimum
# No frequency for (¾, º), assigning minimum
# No frequency for (&, Α), assigning minimum
# No frequency for (Ζ, ĳ), assigning minimum
# No frequency for (θ, Σ), assigning minimum
# No frequency for (≥, Þ), assigning minimum
# No frequency for (‘, =), assigning minimum
# No frequency for (¢, §), assigning minimum
# No frequency for (ù, “), assigning minimum
# No frequency for (ι, ¥), assigning minimum
# No frequency for (_, Β), assigning minimum
# No frequency for (–, ̑d), assigning minimum
# No frequency for (z, π), assigning minimum
# No frequency for (γ, Ι), assigning minimum
# No frequency for (À, ξ), assigning minimum
# No frequency for (ĳ, |), assigning minimum
# No frequency for (≥, Η), assigning minimum
# No frequency for (Ξ, ÷), assigning minimum
# No frequency for (Δ, ĳ), assigning minimum
# No frequency for (τ, ſ), assigning minimum
# No frequency for (κ, x), assigning minimum
# No frequency for (Ç, „), assigning minimum
# No frequency for (z, Θ), assigning minimum
# No frequency for (Ο, ¤), assigning minimum
# No frequency for (¡, ζ), assigning minimum
# No frequency for (-d, ≤), assigning minimum
# No frequency for (‘, δ), assigning minimum
# No frequency for (], Ç), assigning minimum
# No frequency for (÷, Θ), assigning minimum
# No frequency for (ν, ”), assigning minimum
# No frequency for (#, Ŋ), assigning minimum
# No frequency for (ζ, -d), assigning minimum
# No frequency for (ˋd, ½), assigning minimum
# No frequency for (Œ, Π), assigning minimum
# No frequency for (ª, &), assigning minimum
# No frequency for (Β, =), assigning minimum
# No frequency for (¿, ‡), assigning minimum
# No frequency for (<, Ο), assigning minimum
# No frequency for (θ2, n), assigning minimum
# No frequency for (ẞ, √), assigning minimum
# No frequency for (ψ, þ), assigning minimum
# No frequency for (Ĳ, -d), assigning minimum
# No frequency for („, Ŋ), assigning minimum
# No frequency for (t, Ε), assigning minimum
# No frequency for (ω, ‡), assigning minimum
# No frequency for (ω, —), assigning minimum
# No frequency for (Ǝ, γ), assigning minimum
# No frequency for (x, ψ), assigning minimum
# No frequency for (<, Β), assigning minimum
# No frequency for (Œ, {), assigning minimum
# No frequency for (¼, +), assigning minimum
# No frequency for (Ʒ, Β), assigning minimum
# No frequency for (Ε, &), assigning minimum
# No frequency for (Φ, c), assigning minimum
# No frequency for (≃, σ), assigning minimum
# No frequency for (j, §), assigning minimum
# No frequency for (…, u), assigning minimum
# No frequency for (χ, ±), assigning minimum
# No frequency for (γ, ﻿æ), assigning minimum
# No frequency for (˝d, &), assigning minimum
# No frequency for (.d, χ), assigning minimum
# No frequency for (Ρ, d), assigning minimum
# No frequency for (ψ, Ĳ), assigning minimum
# No frequency for (δ, Β), assigning minimum
# No frequency for (γ, ˛d), assigning minimum
# No frequency for (β, ¤), assigning minimum
# No frequency for (Κ, ˝d), assigning minimum
# No frequency for (α, Λ), assigning minimum
# No frequency for (≠, }), assigning minimum
# No frequency for (¨d, ˙d), assigning minimum
# No frequency for (ψ, p), assigning minimum
# No frequency for (υ, Ν), assigning minimum
# No frequency for (Θ, ẞ), assigning minimum
# No frequency for (ŋ, ĳ), assigning minimum
# No frequency for ($, ﻿æ), assigning minimum
# No frequency for (Χ, y), assigning minimum
# No frequency for (ˊd, °d), assigning minimum
# No frequency for (ǝ, ĳ), assigning minimum
# No frequency for (Φ, ‡), assigning minimum
# No frequency for (”, Ζ), assigning minimum
# No frequency for (≥, ©), assigning minimum
# No frequency for (ω, ‚), assigning minimum
# No frequency for (›, ψ), assigning minimum
# No frequency for (w, ©), assigning minimum
# No frequency for (δ, ﻿æ), assigning minimum
# No frequency for (‰, Ω), assigning minimum
# No frequency for (Ρ, a), assigning minimum
# No frequency for (Ç, ̑d), assigning minimum
# No frequency for (f, ¨d), assigning minimum
# No frequency for (Ν, π), assigning minimum
# No frequency for (Þ, ,d), assigning minimum
# No frequency for (c, σ), assigning minimum
# No frequency for (], δ), assigning minimum
# No frequency for (è, Ρ), assigning minimum
# No frequency for (Κ, ù), assigning minimum
# No frequency for (·, Ǝ), assigning minimum
# No frequency for (Λ, Æ), assigning minimum
# No frequency for (), º), assigning minimum
# No frequency for (Œ, ω), assigning minimum
# No frequency for (˛d, ~d), assigning minimum
# No frequency for (Ι, ¤), assigning minimum
# No frequency for (‘, ¸d), assigning minimum
# No frequency for (Β, b), assigning minimum
# No frequency for (ẞ, ,d), assigning minimum
# No frequency for (w, ‡), assigning minimum
# No frequency for (÷, ̑d), assigning minimum
# No frequency for (θ, ſ), assigning minimum
# No frequency for (˝d, (), assigning minimum
# No frequency for (﻿æ, $), assigning minimum
# No frequency for ({, Π), assigning minimum
# No frequency for (è, „), assigning minimum
# No frequency for (ο, ‚), assigning minimum
# No frequency for (≥, φ), assigning minimum
# No frequency for (˘d, @), assigning minimum
# No frequency for (°d, ˉd), assigning minimum
# No frequency for (η, g), assigning minimum
# No frequency for (Υ, %), assigning minimum
# No frequency for (,d, ŋ), assigning minimum
# No frequency for (f, ˇd), assigning minimum
# No frequency for (s, χ), assigning minimum
# No frequency for (°d, é), assigning minimum
# No frequency for (λ, ‰), assigning minimum
# No frequency for (z, Ω), assigning minimum
# No frequency for (Τ, ‰), assigning minimum
# No frequency for (_, ª), assigning minimum
# No frequency for (ŋ, θ2), assigning minimum
# No frequency for (…, ·), assigning minimum
# No frequency for (ζ, ù), assigning minimum
# No frequency for (ξ, „), assigning minimum
# No frequency for (é, ̑d), assigning minimum
# No frequency for (Ǝ, +), assigning minimum
# No frequency for (Χ, ≤), assigning minimum
# No frequency for (Ŋ, ˘d), assigning minimum
# No frequency for (Ç, °), assigning minimum
# No frequency for (}, ß), assigning minimum
# No frequency for (˵d, ¼), assigning minimum
# No frequency for (x, ª), assigning minimum
# No frequency for (ĳ, è), assigning minimum
# No frequency for (‹, ¥), assigning minimum
# No frequency for (Γ, ̑d), assigning minimum
# No frequency for (ˋd, “), assigning minimum
# No frequency for ((, ˇd), assigning minimum
# No frequency for (r, Η), assigning minimum
# No frequency for (_, ’), assigning minimum
# No frequency for (§, Β), assigning minimum
# No frequency for (É, †), assigning minimum
# No frequency for (θ, ç), assigning minimum
# No frequency for (υ, İ), assigning minimum
# No frequency for (¢, f), assigning minimum
# No frequency for (‹, ð), assigning minimum
# No frequency for (˛d, Χ), assigning minimum
# No frequency for (‹, ˵d), assigning minimum
# No frequency for (₩, .d), assigning minimum
# No frequency for (Ʒ, Ð), assigning minimum
# No frequency for (g, «), assigning minimum
# No frequency for (», ~d), assigning minimum
# No frequency for (¿, Ξ), assigning minimum
# No frequency for (ρ, «), assigning minimum
# No frequency for (ſ, $), assigning minimum
# No frequency for (≃, y), assigning minimum
# No frequency for (ĳ, ª), assigning minimum
# No frequency for (κ, §), assigning minimum
# No frequency for (τ, ·), assigning minimum
# No frequency for (c, ‹), assigning minimum
# No frequency for (Ĳ, ˉd), assigning minimum
# No frequency for (ε, „), assigning minimum
# No frequency for (¢, ξ), assigning minimum
# No frequency for (è, ‹), assigning minimum
# No frequency for (c, ¥), assigning minimum
# No frequency for (π, Κ), assigning minimum
# No frequency for (ι, Χ), assigning minimum
# No frequency for (\, ε), assigning minimum
# No frequency for (√, υ), assigning minimum
# No frequency for ({, ŋ), assigning minimum
# No frequency for (#, ι), assigning minimum
# No frequency for (¿, Χ), assigning minimum
# No frequency for (g, Γ), assigning minimum
# No frequency for (ſ, ,d), assigning minimum
# No frequency for (Ζ, ₩), assigning minimum
# No frequency for (_d, È), assigning minimum
# No frequency for (﻿æ, k), assigning minimum
# No frequency for (Ζ, ≤), assigning minimum
# No frequency for (ª, ∞), assigning minimum
# No frequency for (Μ, ˊd), assigning minimum
# No frequency for (ĳ, Ŋ), assigning minimum
# No frequency for (z, Ʒ), assigning minimum
# No frequency for (¸d, φ), assigning minimum
# No frequency for (À, ¥), assigning minimum
# No frequency for (º, Ç), assigning minimum
# No frequency for (Ψ, ˛d), assigning minimum
# No frequency for (’, Δ), assigning minimum
# No frequency for (İ, +), assigning minimum
# No frequency for (», É), assigning minimum
# No frequency for (©, Ç), assigning minimum
# No frequency for (λ, Β), assigning minimum
# No frequency for (Χ, Ĳ), assigning minimum
# No frequency for (~d, ¾), assigning minimum
# No frequency for (Λ, r), assigning minimum
# No frequency for (‚, b), assigning minimum
# No frequency for (≥, ‘), assigning minimum
# No frequency for (Ʒ, ρ), assigning minimum
# No frequency for (ˊd, ˇd), assigning minimum
# No frequency for (/d, ¥), assigning minimum
# No frequency for (ξ, ≥), assigning minimum
# No frequency for (Δ, ǝ), assigning minimum
# No frequency for (ρ, ˊd), assigning minimum
# No frequency for (è, ¼), assigning minimum
# No frequency for (İ, °d), assigning minimum
# No frequency for (®, f), assigning minimum
# No frequency for (Ο, ¿), assigning minimum
# No frequency for (˵d, =), assigning minimum
# No frequency for (¾, }), assigning minimum
# No frequency for (/d, _), assigning minimum
# No frequency for (÷, m), assigning minimum
# No frequency for (=, ˛d), assigning minimum
# No frequency for (º, θ), assigning minimum
# No frequency for (±, ¸d), assigning minimum
# No frequency for (Ν, f), assigning minimum
# No frequency for (≤, ŋ), assigning minimum
# No frequency for (ẞ, υ), assigning minimum
# No frequency for (ˊd, {), assigning minimum
# No frequency for ([, Φ), assigning minimum
# No frequency for (Ǝ, g), assigning minimum
# No frequency for (È, ˝d), assigning minimum
# No frequency for (Υ, ŋ), assigning minimum
# No frequency for (—, £), assigning minimum
# No frequency for (l, κ), assigning minimum
# No frequency for (.d, Π), assigning minimum
# No frequency for (Ĳ, ˇd), assigning minimum
# No frequency for (‹, Β), assigning minimum
# No frequency for (Ε, \), assigning minimum
# No frequency for (Ǝ, Μ), assigning minimum
# No frequency for (α, …), assigning minimum
# No frequency for (Α, §), assigning minimum
# No frequency for (£, œ), assigning minimum
# No frequency for (s, Λ), assigning minimum
# No frequency for (Κ, ¨d), assigning minimum
# No frequency for (k, Ρ), assigning minimum
# No frequency for (¥, †), assigning minimum
# No frequency for (Ν, $), assigning minimum
# No frequency for (x, ¾), assigning minimum
# No frequency for (‹, τ), assigning minimum
# No frequency for (.d, ª), assigning minimum
# No frequency for (÷, g), assigning minimum
# No frequency for (﻿æ, £), assigning minimum
# No frequency for (Ξ, p), assigning minimum
# No frequency for (-d, À), assigning minimum
# No frequency for (b, ρ), assigning minimum
# No frequency for (-d, Œ), assigning minimum
# No frequency for (¢, μ), assigning minimum
# No frequency for (Ʒ, ≠), assigning minimum
# No frequency for (‡, Ν), assigning minimum
# No frequency for (m, Π), assigning minimum
# No frequency for (Σ, ĳ), assigning minimum
# No frequency for (₩, /d), assigning minimum
# No frequency for (…, s), assigning minimum
# No frequency for (ρ, ‰), assigning minimum
# No frequency for (%, Ζ), assigning minimum
# No frequency for (‡, α), assigning minimum
# No frequency for (”, π), assigning minimum
# No frequency for (”, /d), assigning minimum
# No frequency for (º, þ), assigning minimum
# No frequency for (», §), assigning minimum
# No frequency for (c, ‰), assigning minimum
# No frequency for (é, ι), assigning minimum
# No frequency for (Ρ, χ), assigning minimum
# No frequency for (^d, “), assigning minimum
# No frequency for (”, ©), assigning minimum
# No frequency for (α, ®), assigning minimum
# No frequency for (﻿æ, é), assigning minimum
# No frequency for (ω, b), assigning minimum
# No frequency for (¥, υ), assigning minimum
# No frequency for (q, Μ), assigning minimum
# No frequency for (‘, Ρ), assigning minimum
# No frequency for (γ, é), assigning minimum
# No frequency for (&, Ʒ), assigning minimum
# No frequency for (À, ≠), assigning minimum
# No frequency for (Ψ, φ), assigning minimum
# No frequency for (”, ˉd), assigning minimum
# No frequency for (×, ‰), assigning minimum
# No frequency for (˘d, Ι), assigning minimum
# No frequency for (ŋ, ρ), assigning minimum
# No frequency for (χ, ˇd), assigning minimum
# No frequency for (δ, »), assigning minimum
# No frequency for (Δ, °d), assigning minimum
# No frequency for (‹, ç), assigning minimum
# No frequency for (m, Ç), assigning minimum
# No frequency for (&, ª), assigning minimum
# No frequency for (√, ≃), assigning minimum
# No frequency for (t, ̑d), assigning minimum
# No frequency for (z, Δ), assigning minimum
# No frequency for (/d, σ), assigning minimum
# No frequency for (n, ẞ), assigning minimum
# No frequency for ($, —), assigning minimum
# No frequency for (<, »), assigning minimum
# No frequency for (Θ, ζ), assigning minimum
# No frequency for (Β, >), assigning minimum
# No frequency for (,d, ſ), assigning minimum
# No frequency for (ª, ª), assigning minimum
# No frequency for (›, ι), assigning minimum
# No frequency for (ˋd, Κ), assigning minimum
# No frequency for (̑d, «), assigning minimum
# No frequency for (¤, ≠), assigning minimum
# No frequency for (k, Η), assigning minimum
# No frequency for (Ο, f), assigning minimum
# No frequency for (@, ≠), assigning minimum
# No frequency for (μ, ~d), assigning minimum
# No frequency for (ª, u), assigning minimum
# No frequency for (j, ®), assigning minimum
# No frequency for (Ð, α), assigning minimum
# No frequency for (θ2, a), assigning minimum
# No frequency for (ι, İ), assigning minimum
# No frequency for (k, Ε), assigning minimum
# No frequency for (η, ~d), assigning minimum
# No frequency for (&, μ), assigning minimum
# No frequency for (ŋ, ¨d), assigning minimum
# No frequency for (α, ʒ), assigning minimum
# No frequency for (Ʒ, Þ), assigning minimum
# No frequency for (ù, º), assigning minimum
# No frequency for (τ, ¢), assigning minimum
# No frequency for (Σ, ˉd), assigning minimum
# No frequency for (Ω, Φ), assigning minimum
# No frequency for (̑d, ”), assigning minimum
# No frequency for („, Τ), assigning minimum
# No frequency for (≠, ≥), assigning minimum
# No frequency for (#, «), assigning minimum
# No frequency for (‡, k), assigning minimum
# No frequency for (“, ˘d), assigning minimum
# No frequency for (Œ, +), assigning minimum
# No frequency for (<, ~d), assigning minimum
# No frequency for (ζ, Η), assigning minimum
# No frequency for (Ζ, |), assigning minimum
# No frequency for (̑d, ∞), assigning minimum
# No frequency for (Β, π), assigning minimum
# No frequency for (.d, ψ), assigning minimum
# No frequency for (ι, ẞ), assigning minimum
# No frequency for (Γ, ½), assigning minimum
# No frequency for (δ, ‡), assigning minimum
# No frequency for (¡, ’), assigning minimum
# No frequency for (∞, ı), assigning minimum
# No frequency for (—, ˉd), assigning minimum
# No frequency for (¤, λ), assigning minimum
# No frequency for (h, ˋd), assigning minimum
# No frequency for (), y), assigning minimum
# No frequency for (ſ, δ), assigning minimum
# No frequency for (@, ˛d), assigning minimum
# No frequency for (‚, –), assigning minimum
# No frequency for (φ, ʒ), assigning minimum
# No frequency for (ù, Η), assigning minimum
# No frequency for (,d, %), assigning minimum
# No frequency for (/d, α), assigning minimum
# No frequency for (}, Ο), assigning minimum
# No frequency for (ε, Ι), assigning minimum
# No frequency for (≤, Ĳ), assigning minimum
# No frequency for (Ǝ, ^d), assigning minimum
# No frequency for (Æ, ¿), assigning minimum
# No frequency for (g, İ), assigning minimum
# No frequency for (©, $), assigning minimum
# No frequency for (≃, ¼), assigning minimum
# No frequency for (Ζ, q), assigning minimum
# No frequency for (ŋ, ˋd), assigning minimum
# No frequency for (ß, ©), assigning minimum
# No frequency for (˛d, ®), assigning minimum
# No frequency for (ξ, Ο), assigning minimum
# No frequency for (Ε, ‰), assigning minimum
# No frequency for (‡, ̑d), assigning minimum
# No frequency for (·, ‹), assigning minimum
# No frequency for (Ŋ, d), assigning minimum
# No frequency for (ß, ,d), assigning minimum
# No frequency for (θ, Λ), assigning minimum
# No frequency for (·, ¼), assigning minimum
# No frequency for (Α, „), assigning minimum
# No frequency for (Ν, ·), assigning minimum
# No frequency for (ẞ, ð), assigning minimum
# No frequency for (<, Ʒ), assigning minimum
# No frequency for (,d, Η), assigning minimum
# No frequency for (Γ, †), assigning minimum
# No frequency for (’, η), assigning minimum
# No frequency for (¢, ›), assigning minimum
# No frequency for (μ, …), assigning minimum
# No frequency for (_d, ˊd), assigning minimum
# No frequency for («, §), assigning minimum
# No frequency for (ª, ½), assigning minimum
# No frequency for (©, ẞ), assigning minimum
# No frequency for (Ǝ, *), assigning minimum
# No frequency for (j, Γ), assigning minimum
# No frequency for (‑, θ2), assigning minimum
# No frequency for (Ð, ‰), assigning minimum
# No frequency for (», †), assigning minimum
# No frequency for (Ζ, ǝ), assigning minimum
# No frequency for (§, ŋ), assigning minimum
# No frequency for (¸d, ¡), assigning minimum
# No frequency for (Ŋ, Ǝ), assigning minimum
# No frequency for (é, κ), assigning minimum
# No frequency for (Ν, θ2), assigning minimum
# No frequency for (½, Β), assigning minimum
# No frequency for (Χ, Œ), assigning minimum
# No frequency for (®, _d), assigning minimum
# No frequency for (İ, ₩), assigning minimum
# No frequency for (h, Κ), assigning minimum
# No frequency for (α, Ç), assigning minimum
# No frequency for (ˇd, Υ), assigning minimum
# No frequency for ([, İ), assigning minimum
# No frequency for (≤, Κ), assigning minimum
# No frequency for (-, ¼), assigning minimum
# No frequency for (#, ˘d), assigning minimum
# No frequency for (Ʒ, Ρ), assigning minimum
# No frequency for (¾, Π), assigning minimum
# No frequency for (#, Ĳ), assigning minimum
# No frequency for (¼, ©), assigning minimum
# No frequency for ({, ¾), assigning minimum
# No frequency for (-d, «), assigning minimum
# No frequency for (_d, Ξ), assigning minimum
# No frequency for (b, θ2), assigning minimum
# No frequency for (ˉd, ½), assigning minimum
# No frequency for (Ζ, ¤), assigning minimum
# No frequency for (ı, „), assigning minimum
# No frequency for ([, ˉd), assigning minimum
# No frequency for (Λ, ”), assigning minimum
# No frequency for (Ι, »), assigning minimum
# No frequency for (d, Θ), assigning minimum
# No frequency for (¤, {), assigning minimum
# No frequency for (f, °d), assigning minimum
# No frequency for (ª, f), assigning minimum
# No frequency for (¨d, †), assigning minimum
# No frequency for (κ, ›), assigning minimum
# No frequency for (l, ω), assigning minimum
# No frequency for (ψ, ¾), assigning minimum
# No frequency for (¿, …), assigning minimum
# No frequency for (Ξ, ,d), assigning minimum
# No frequency for (^d, ˉd), assigning minimum
# No frequency for (Ν, δ), assigning minimum
# No frequency for (Ν, &), assigning minimum
# No frequency for (/d, –), assigning minimum
# No frequency for (ˇd, Ο), assigning minimum
# No frequency for (¢, É), assigning minimum
# No frequency for (®, Θ), assigning minimum
# No frequency for (˝d, \), assigning minimum
# No frequency for (À, ‑), assigning minimum
# No frequency for (Ŋ, ζ), assigning minimum
# No frequency for (Ψ, β), assigning minimum
# No frequency for (Κ, ]), assigning minimum
# No frequency for (₩, Υ), assigning minimum
# No frequency for (ξ, *), assigning minimum
# No frequency for (₩, Ξ), assigning minimum
# No frequency for (˙d, √), assigning minimum
# No frequency for (é, Μ), assigning minimum
# No frequency for (_d, ̑d), assigning minimum
# No frequency for (ĳ, z), assigning minimum
# No frequency for (ſ, j), assigning minimum
# No frequency for (η, &), assigning minimum
# No frequency for (@, è), assigning minimum
# No frequency for (˙d, ŋ), assigning minimum
# No frequency for (©, ‡), assigning minimum
# No frequency for (ˋd, ˊd), assigning minimum
# No frequency for (˝d, à), assigning minimum
# No frequency for (}, Δ), assigning minimum
# No frequency for (ẞ, κ), assigning minimum
# No frequency for (º, ˝d), assigning minimum
# No frequency for (ρ, <), assigning minimum
# No frequency for (—, Θ), assigning minimum
# No frequency for (Σ, œ), assigning minimum
# No frequency for (Ν, ©), assigning minimum
# No frequency for (μ, ˘d), assigning minimum
# No frequency for (κ, „), assigning minimum
# No frequency for (q, θ2), assigning minimum
# No frequency for (Γ, -d), assigning minimum
# No frequency for (À, θ2), assigning minimum
# No frequency for (], ˝d), assigning minimum
# No frequency for (÷, ×), assigning minimum
# No frequency for (ſ, Ω), assigning minimum
# No frequency for (≤, ˛d), assigning minimum
# No frequency for (q, Γ), assigning minimum
# No frequency for (π, ẞ), assigning minimum
# No frequency for (Ð, –), assigning minimum
# No frequency for (“, ˇd), assigning minimum
# No frequency for (Ç, ¸d), assigning minimum
# No frequency for (Φ, ù), assigning minimum
# No frequency for (Ĳ, z), assigning minimum
# No frequency for (b, ¾), assigning minimum
# No frequency for (d, Ǝ), assigning minimum
# No frequency for (ẞ, ˊd), assigning minimum
# No frequency for (À, è), assigning minimum
# No frequency for (ω, İ), assigning minimum
# No frequency for (≠, „), assigning minimum
# No frequency for (@, .d), assigning minimum
# No frequency for (Œ, ˉd), assigning minimum
# No frequency for (¢, @), assigning minimum
# No frequency for (%, º), assigning minimum
# No frequency for (,d, w), assigning minimum
# No frequency for (≥, Δ), assigning minimum
# No frequency for (…, ¼), assigning minimum
# No frequency for (þ, Ξ), assigning minimum
# No frequency for (k, Þ), assigning minimum
# No frequency for (¸d, √), assigning minimum
# No frequency for (_d, ‹), assigning minimum
# No frequency for (‘, ﻿æ), assigning minimum
# No frequency for (z, Α), assigning minimum
# No frequency for (Τ, ν), assigning minimum
# No frequency for (Π, j), assigning minimum
# No frequency for (Æ, σ), assigning minimum
# No frequency for (-, ‚), assigning minimum
# No frequency for (Μ, ¿), assigning minimum
# No frequency for (Μ, h), assigning minimum
# No frequency for (ω, ẞ), assigning minimum
# No frequency for (ν, z), assigning minimum
# No frequency for (Τ, °), assigning minimum
# No frequency for (n, ˝d), assigning minimum
# No frequency for (&, ₩), assigning minimum
# No frequency for (ª, Β), assigning minimum
# No frequency for (˙d, #), assigning minimum
# No frequency for (ω, &), assigning minimum
# No frequency for (≥, Λ), assigning minimum
# No frequency for (j, π), assigning minimum
# No frequency for (±, Ǝ), assigning minimum
# No frequency for (¡, _), assigning minimum
# No frequency for (¾, b), assigning minimum
# No frequency for (ν, œ), assigning minimum
# No frequency for (Δ, É), assigning minimum
# No frequency for (ν, ˵d), assigning minimum
# No frequency for (τ, Μ), assigning minimum
# No frequency for (ω, Θ), assigning minimum
# No frequency for (È, ˙d), assigning minimum
# No frequency for (Ð, \), assigning minimum
# No frequency for (ç, π), assigning minimum
# No frequency for (δ, Μ), assigning minimum
# No frequency for (μ, ≥), assigning minimum
# No frequency for (Ʒ, ¾), assigning minimum
# No frequency for (‰, À), assigning minimum
# No frequency for (Μ, ≤), assigning minimum
# No frequency for (Δ, Ψ), assigning minimum
# No frequency for (p, χ), assigning minimum
# No frequency for (·, ˝d), assigning minimum
# No frequency for (À, z), assigning minimum
# No frequency for (﻿æ, ŋ), assigning minimum
# No frequency for (–, Ʒ), assigning minimum
# No frequency for (∞, ω), assigning minimum
# No frequency for (Ψ, Σ), assigning minimum
# No frequency for (c, ‡), assigning minimum
# No frequency for (Ο, k), assigning minimum
# No frequency for (°, ð), assigning minimum
# No frequency for (+, ß), assigning minimum
# No frequency for (œ, .d), assigning minimum
# No frequency for (ù, η), assigning minimum
# No frequency for (Ι, ﻿æ), assigning minimum
# No frequency for (è, £), assigning minimum
# No frequency for (#, Ρ), assigning minimum
# No frequency for (‡, j), assigning minimum
# No frequency for (Ʒ, …), assigning minimum
# No frequency for (¿, ο), assigning minimum
# No frequency for (¥, _), assigning minimum
# No frequency for (×, ‡), assigning minimum
# No frequency for (Þ, Π), assigning minimum
# No frequency for (º, ο), assigning minimum
# No frequency for (ª, ο), assigning minimum
# No frequency for (/d, \), assigning minimum
# No frequency for (Λ, ¨d), assigning minimum
# No frequency for (¸d, ζ), assigning minimum
# No frequency for (˘d, ¼), assigning minimum
# No frequency for (·, ’), assigning minimum
# No frequency for (¥, β), assigning minimum
# No frequency for (Χ, u), assigning minimum
# No frequency for (ˊd, ˛d), assigning minimum
# No frequency for (η, y), assigning minimum
# No frequency for (>, Υ), assigning minimum
# No frequency for (~d, ˛d), assigning minimum
# No frequency for (≃, ‡), assigning minimum
# No frequency for (˘d, «), assigning minimum
# No frequency for (Ŋ, γ), assigning minimum
# No frequency for (n, Θ), assigning minimum
# No frequency for (ǝ, ₩), assigning minimum
# No frequency for (Κ, p), assigning minimum
# No frequency for (¢, ç), assigning minimum
# No frequency for (﻿æ, t), assigning minimum
# No frequency for (ç, Λ), assigning minimum
# No frequency for (È, Λ), assigning minimum
# No frequency for (≃, β), assigning minimum
# No frequency for (Δ, ˉd), assigning minimum
# No frequency for (Ω, h), assigning minimum
# No frequency for (÷, Ψ), assigning minimum
# No frequency for (θ, _d), assigning minimum
# No frequency for (Ξ, θ2), assigning minimum
# No frequency for (Κ, Ŋ), assigning minimum
# No frequency for (χ, z), assigning minimum
# No frequency for (½, β), assigning minimum
# No frequency for (ξ, †), assigning minimum
# No frequency for (“, ω), assigning minimum
# No frequency for (Æ, γ), assigning minimum
# No frequency for (υ, ÷), assigning minimum
# No frequency for (≥, ≠), assigning minimum
# No frequency for (﻿æ, ν), assigning minimum
# No frequency for (ο, {), assigning minimum
# No frequency for (Ζ, ẞ), assigning minimum
# No frequency for (̑d, à), assigning minimum
# No frequency for (ʒ, ˘d), assigning minimum
# No frequency for (Φ, ,d), assigning minimum
# No frequency for (‰, τ), assigning minimum
# No frequency for (﻿æ, υ), assigning minimum
# No frequency for (α, ©), assigning minimum
# No frequency for (θ, §), assigning minimum
# No frequency for (Υ, l), assigning minimum
# No frequency for (Þ, ρ), assigning minimum
# No frequency for (Θ, ≥), assigning minimum
# No frequency for (·, ‑), assigning minimum
# No frequency for (Ω, }), assigning minimum
# No frequency for (θ2, δ), assigning minimum
# No frequency for (Ŋ, Ξ), assigning minimum
# No frequency for (ι, q), assigning minimum
# No frequency for (þ, ı), assigning minimum
# No frequency for (], χ), assigning minimum
# No frequency for (Ξ, ﻿æ), assigning minimum
# No frequency for (η, ¿), assigning minimum
# No frequency for (r, £), assigning minimum
# No frequency for (Ψ, Β), assigning minimum
# No frequency for (≠, Σ), assigning minimum
# No frequency for (π, l), assigning minimum
# No frequency for (ˋd, Œ), assigning minimum
# No frequency for (Ç, £), assigning minimum
# No frequency for (e, Μ), assigning minimum
# No frequency for (ʒ, …), assigning minimum
# No frequency for (], ζ), assigning minimum
# No frequency for (∞, κ), assigning minimum
# No frequency for (ο, _), assigning minimum
# No frequency for (σ, ˉd), assigning minimum
# No frequency for (Γ, È), assigning minimum
# No frequency for (‹, χ), assigning minimum
# No frequency for (>, ¡), assigning minimum
# No frequency for (Θ, }), assigning minimum
# No frequency for (n, Ð), assigning minimum
# No frequency for (υ, e), assigning minimum
# No frequency for (κ, ð), assigning minimum
# No frequency for (υ, ‘), assigning minimum
# No frequency for (β, ¨d), assigning minimum
# No frequency for (ν, ˊd), assigning minimum
# No frequency for (À, y), assigning minimum
# No frequency for (‘, .d), assigning minimum
# No frequency for (Ζ, ¢), assigning minimum
# No frequency for (É, ‚), assigning minimum
# No frequency for (à, ∞), assigning minimum
# No frequency for (,d, _), assigning minimum
# No frequency for (\, Ζ), assigning minimum
# No frequency for (Ν, ’), assigning minimum
# No frequency for (˵d, Ŋ), assigning minimum
# No frequency for (§, Φ), assigning minimum
# No frequency for (þ, Β), assigning minimum
# No frequency for (à, _d), assigning minimum
# No frequency for („, κ), assigning minimum
# No frequency for (¸d, ®), assigning minimum
# No frequency for (›, ½), assigning minimum
# No frequency for (γ, ̑d), assigning minimum
# No frequency for (°d, Ε), assigning minimum
# No frequency for (ð, ˇd), assigning minimum
# No frequency for (q, ½), assigning minimum
# No frequency for (İ, _d), assigning minimum
# No frequency for (†, ¾), assigning minimum
# No frequency for (›, Ρ), assigning minimum
# No frequency for (Η, ζ), assigning minimum
# No frequency for (≤, ¤), assigning minimum
# No frequency for (Ĳ, .d), assigning minimum
# No frequency for (ı, ˵d), assigning minimum
# No frequency for (É, Ʒ), assigning minimum
# No frequency for (Þ, ˘d), assigning minimum
# No frequency for (®, è), assigning minimum
# No frequency for (ẞ, m), assigning minimum
# No frequency for (Ð, ι), assigning minimum
# No frequency for (Ο, ſ), assigning minimum
# No frequency for (¥, _d), assigning minimum
# No frequency for (è, ĳ), assigning minimum
# No frequency for (˘d, è), assigning minimum
# No frequency for (∞, ‑), assigning minimum
# No frequency for (Υ, ‑), assigning minimum
# No frequency for (ˉd, °d), assigning minimum
# No frequency for (}, Β), assigning minimum
# No frequency for (Ç, ψ), assigning minimum
# No frequency for (¢, ˵d), assigning minimum
# No frequency for (r, Χ), assigning minimum
# No frequency for (θ, ĳ), assigning minimum
# No frequency for (£, _), assigning minimum
# No frequency for (x, χ), assigning minimum
# No frequency for (τ, º), assigning minimum
# No frequency for (», φ), assigning minimum
# No frequency for (°d, ‡), assigning minimum
# No frequency for (,d, »), assigning minimum
# No frequency for (Œ, \), assigning minimum
# No frequency for (ρ, Ŋ), assigning minimum
# No frequency for (ψ, ˵d), assigning minimum
# No frequency for (…, ε), assigning minimum
# No frequency for (θ2, Τ), assigning minimum
# No frequency for (≤, ι), assigning minimum
# No frequency for (Ρ, ±), assigning minimum
# No frequency for (‡, «), assigning minimum
# No frequency for (w, ˉd), assigning minimum
# No frequency for (Ʒ, /d), assigning minimum
# No frequency for (£, y), assigning minimum
# No frequency for (≥, μ), assigning minimum
# No frequency for (̑d, Ǝ), assigning minimum
# No frequency for (ẞ, ω), assigning minimum
# No frequency for (z, ̑d), assigning minimum
# No frequency for ({, Ʒ), assigning minimum
# No frequency for (», ¨d), assigning minimum
# No frequency for (λ, ﻿æ), assigning minimum
# No frequency for (j, ±), assigning minimum
# No frequency for (º, -d), assigning minimum
# No frequency for (Μ, γ), assigning minimum
# No frequency for (Α, +), assigning minimum
# No frequency for (±, Ξ), assigning minimum
# No frequency for (ω, ˘d), assigning minimum
# No frequency for (‚, ÷), assigning minimum
# No frequency for (d, -d), assigning minimum
# No frequency for (”, Æ), assigning minimum
# No frequency for (†, π), assigning minimum
# No frequency for (\, Ρ), assigning minimum
# No frequency for (ψ, ﻿æ), assigning minimum
# No frequency for (μ, -d), assigning minimum
# No frequency for (.d, ^d), assigning minimum
# No frequency for (÷, Γ), assigning minimum
# No frequency for (v, ﻿æ), assigning minimum
# No frequency for (μ, Ǝ), assigning minimum
# No frequency for (¡, δ), assigning minimum
# No frequency for (ξ, È), assigning minimum
# No frequency for (°d, ›), assigning minimum
# No frequency for (Τ, ˘d), assigning minimum
# No frequency for (œ, ρ), assigning minimum
# No frequency for (^d, ¥), assigning minimum
# No frequency for (﻿æ, ˝d), assigning minimum
# No frequency for (ǝ, \), assigning minimum
# No frequency for (θ, θ2), assigning minimum
# No frequency for (ε, ß), assigning minimum
# No frequency for (ξ, Κ), assigning minimum
# No frequency for (ç, Θ), assigning minimum
# No frequency for (ρ, ¾), assigning minimum
# No frequency for (̑d, ˝d), assigning minimum
# No frequency for (œ, _), assigning minimum
# No frequency for (﻿æ, ~d), assigning minimum
# No frequency for (o, Ð), assigning minimum
# No frequency for (>, υ), assigning minimum
# No frequency for (%, Κ), assigning minimum
# No frequency for (Ð, ÷), assigning minimum
# No frequency for (/d, Ψ), assigning minimum
# No frequency for (ª, Ρ), assigning minimum
# No frequency for (ç, λ), assigning minimum
# No frequency for (π, ſ), assigning minimum
# No frequency for (v, ¿), assigning minimum
# No frequency for (¾, Μ), assigning minimum
# No frequency for (Ξ, œ), assigning minimum
# No frequency for (Ĳ, υ), assigning minimum
# No frequency for (ω, œ), assigning minimum
# No frequency for (.d, «), assigning minimum
# No frequency for (§, Λ), assigning minimum
# No frequency for (≤, “), assigning minimum
# No frequency for (º, Ʒ), assigning minimum
# No frequency for (Ο, m), assigning minimum
# No frequency for (Æ, ˘d), assigning minimum
# No frequency for (/d, ˉd), assigning minimum
# No frequency for ({, þ), assigning minimum
# No frequency for (%, λ), assigning minimum
# No frequency for (β, ¢), assigning minimum
# No frequency for (ç, ®), assigning minimum
# No frequency for (®, Ð), assigning minimum
# No frequency for (﻿æ, g), assigning minimum
# No frequency for (·, ˇd), assigning minimum
# No frequency for (‡, σ), assigning minimum
# No frequency for (φ, ˉd), assigning minimum
# No frequency for (Β, ½), assigning minimum
# No frequency for (Η, ‹), assigning minimum
# No frequency for (İ, Æ), assigning minimum
# No frequency for (λ, ǝ), assigning minimum
# No frequency for (θ2, Δ), assigning minimum
# No frequency for (°d, ‰), assigning minimum
# No frequency for (), ð), assigning minimum
# No frequency for (Þ, ≠), assigning minimum
# No frequency for (-d, ˘d), assigning minimum
# No frequency for (¨d, Ð), assigning minimum
# No frequency for (˝d, °), assigning minimum
# No frequency for (*, º), assigning minimum
# No frequency for (≠, σ), assigning minimum
# No frequency for (±, İ), assigning minimum
# No frequency for (›, ≠), assigning minimum
# No frequency for (≃, ˛d), assigning minimum
# No frequency for (Δ, >), assigning minimum
# No frequency for (Ψ, ≤), assigning minimum
# No frequency for (ı, ˊd), assigning minimum
# No frequency for (p, Ε), assigning minimum
# No frequency for (‡, ‰), assigning minimum
# No frequency for (Æ, $), assigning minimum
# No frequency for (μ, ù), assigning minimum
# No frequency for (Δ, ç), assigning minimum
# No frequency for (√, þ), assigning minimum
# No frequency for (·, ˛d), assigning minimum
# No frequency for (k, Π), assigning minimum
# No frequency for (e, Β), assigning minimum
# No frequency for (δ, À), assigning minimum
# No frequency for (º, ﻿æ), assigning minimum
# No frequency for (‚, .d), assigning minimum
# No frequency for (é, Þ), assigning minimum
# No frequency for («, ù), assigning minimum
# No frequency for (Π, β), assigning minimum
# No frequency for (’, σ), assigning minimum
# No frequency for (η, j), assigning minimum
# No frequency for (Ι, „), assigning minimum
# No frequency for (√, Α), assigning minimum
# No frequency for (ο, }), assigning minimum
# No frequency for (Τ, †), assigning minimum
# No frequency for (δ, Ŋ), assigning minimum
# No frequency for (l, ‡), assigning minimum
# No frequency for (/d, ẞ), assigning minimum
# No frequency for (Ξ, —), assigning minimum
# No frequency for (±, χ), assigning minimum
# No frequency for (˝d, ω), assigning minimum
# No frequency for (/d, w), assigning minimum
# No frequency for (φ, ,d), assigning minimum
# No frequency for (±, ®), assigning minimum
# No frequency for (é, Ð), assigning minimum
# No frequency for (<, ˝d), assigning minimum
# No frequency for (×, #), assigning minimum
# No frequency for (Θ, φ), assigning minimum
# No frequency for (Β, ˛d), assigning minimum
# No frequency for (¤, ʒ), assigning minimum
# No frequency for (_d, ‡), assigning minimum
# No frequency for (°d, θ2), assigning minimum
# No frequency for (ξ, º), assigning minimum
# No frequency for (≃, ›), assigning minimum
# No frequency for (Φ, Θ), assigning minimum
# No frequency for (İ, Ω), assigning minimum
# No frequency for (q, ŋ), assigning minimum
# No frequency for (Þ, ı), assigning minimum
# No frequency for (ν, b), assigning minimum
# No frequency for (\, ≠), assigning minimum
# No frequency for (˘d, À), assigning minimum
# No frequency for (Ω, ˝d), assigning minimum
# No frequency for (Η, ˘d), assigning minimum
# No frequency for ({, Β), assigning minimum
# No frequency for (+, ẞ), assigning minimum
# No frequency for (Ψ, i), assigning minimum
# No frequency for (ˇd, Φ), assigning minimum
# No frequency for (°d, α), assigning minimum
# No frequency for (ˋd, η), assigning minimum
# No frequency for (Μ, Æ), assigning minimum
# No frequency for (‘, ®), assigning minimum
# No frequency for (Ρ, γ), assigning minimum
# No frequency for (κ, ¥), assigning minimum
# No frequency for (x, σ), assigning minimum
# No frequency for (Þ, >), assigning minimum
# No frequency for (Ĳ, h), assigning minimum
# No frequency for (χ, -d), assigning minimum
# No frequency for (ν, Μ), assigning minimum
# No frequency for (Ǝ, q), assigning minimum
# No frequency for (Ǝ, «), assigning minimum
# No frequency for (Ψ, σ), assigning minimum
# No frequency for (f, ẞ), assigning minimum
# No frequency for (Γ, ∞), assigning minimum
# No frequency for (≠, Ŋ), assigning minimum
# No frequency for (°d, ¿), assigning minimum
# No frequency for (Τ, ¨d), assigning minimum
# No frequency for (g, Ξ), assigning minimum
# No frequency for (‹, %), assigning minimum
# No frequency for (˛d, .d), assigning minimum
# No frequency for (ι, ‡), assigning minimum
# No frequency for (@, ˊd), assigning minimum
# No frequency for (Ο, γ), assigning minimum
# No frequency for (‹, +), assigning minimum
# No frequency for (Η, ˇd), assigning minimum
# No frequency for (þ, κ), assigning minimum
# No frequency for (r, σ), assigning minimum
# No frequency for ([, ˙d), assigning minimum
# No frequency for (×, ¾), assigning minimum
# No frequency for (α, ĳ), assigning minimum
# No frequency for (ˋd, √), assigning minimum
# No frequency for (Α, <), assigning minimum
# No frequency for (,d, Ζ), assigning minimum
# No frequency for (<, Ι), assigning minimum
# No frequency for (], Œ), assigning minimum
# No frequency for (w, θ), assigning minimum
# No frequency for (ψ, ‚), assigning minimum
# No frequency for (≥, β), assigning minimum
# No frequency for (‰, ‘), assigning minimum
# No frequency for (Ĳ, Η), assigning minimum
# No frequency for (œ, Γ), assigning minimum
# No frequency for (ĳ, *), assigning minimum
# No frequency for (μ, Χ), assigning minimum
# No frequency for (h, ∞), assigning minimum
# No frequency for (¿, [), assigning minimum
# No frequency for (ĳ, ∞), assigning minimum
# No frequency for (Κ, ∞), assigning minimum
# No frequency for (Π, w), assigning minimum
# No frequency for (@, ζ), assigning minimum
# No frequency for (¿, “), assigning minimum
# No frequency for (≥, ≃), assigning minimum
# No frequency for (À, >), assigning minimum
# No frequency for (˵d, ˉd), assigning minimum
# No frequency for (,d, Β), assigning minimum
# No frequency for (/d, /d), assigning minimum
# No frequency for (ù, √), assigning minimum
# No frequency for (Π, ð), assigning minimum
# No frequency for (·, Ĳ), assigning minimum
# No frequency for (ˋd, °), assigning minimum
# No frequency for (>, „), assigning minimum
# No frequency for (Ð, ‚), assigning minimum
# No frequency for (ç, θ), assigning minimum
# No frequency for (ſ, ˙d), assigning minimum
# No frequency for (y, -d), assigning minimum
# No frequency for (Ο, #), assigning minimum
# No frequency for (Ʒ, ˊd), assigning minimum
# No frequency for (≥, i), assigning minimum
# No frequency for (₩, ×), assigning minimum
# No frequency for (˛d, ÷), assigning minimum
# No frequency for (Γ, —), assigning minimum
# No frequency for (ˇd, /d), assigning minimum
# ...
#   (u'\xe8', u'\u2039'): 0.0,
#   (u'c', u'\xa5'): 0.0,
#   (u'@', u'\u201a'): 2.5406145562380896e-11,
#   (u'l', u'\u02cad'): 2.5406145562380905e-09,
#   (u'\xde', u'\xc8'): 2.5406145562380896e-11,
#   (u'\u03b9', u'\u03a7'): 0.0,
#   (u'\\', u'\u03b5'): 0.0,
#   (u'u', u'\u02c9d'): 2.1087567034784866e-06,
#   (u'\u221a', u'\u03c5'): 0.0,
#   (u'{', u'\u014b'): 0.0,
#   (u'#', u'\u03b9'): 0.0,
#   (u'\xa2', u';'): 2.5406145562380896e-11,
#   (u'\u039f', u'\u0393'): 2.7946760118618985e-10,
#   (u'\xbf', u'\u03a7'): 0.0,
#   (u'g', u'\u0393'): 0.0,
#   (u'\u02d9d', u'o'): 2.240822038601995e-08,
#   (u'\u017f', u',d'): 0.0,
#   (u'\u0396', u'\u20a9'): 0.0,
#   (u'^d', u'^d'): 0.0,
#   (u'_d', u'\xc8'): 0.0,
#   (u'\ufeff\xe6', u'k'): 0.0,
#   (u'o', u'p'): 0.0014790758164678613,
#   (u'\u0396', u'\u2264'): 0.0,
#   (u'\xaa', u'\u221e'): 0.0,
#   (u':', u'\u2011'): 2.5406145562380896e-11,
#   (u'\u02cad', u'\xf9'): 2.5406145562380896e-11,
#   (u'\u03bb', u'e'): 3.048737467485707e-10,
#   (u'\u039c', u'\u02cad'): 0.0,
#   (u'a', u'?'): 1.4076528167312199e-07,
#   (u'\u0133', u'\u014a'): 0.0,
#   (u'z', u'\u01b7'): 0.0,
#   (u'\xb8d', u'\u03c6'): 0.0,
#   (u'\xba', u'\xc7'): 0.0,
#   (u'\u03a8', u'\u02dbd'): 0.0,
#   (u'\u039b', u'\u0153'): 0.0,
#   (u'i', u'\u03b1'): 2.0324916449904717e-10,
#   (u'\u2019', u'\u0394'): 0.0,
#   (u'\u0130', u'+'): 0.0,
#   (u'\xbb', u'\xc9'): 0.0,
#   (u'*', u'\u03c0'): 4.573106201228562e-10,
#   (u'\xa9', u'\xc7'): 0.0,
#   (u'\u03bb', u'\u0392'): 0.0,
#   (u'\u017f', u','): 1.7784301893666626e-10,
#   (u'\u03a7', u'\u0132'): 0.0,
#   (u'~d', u'\xbe'): 0.0,
#   (u'\u039b', u'r'): 0.0,
#   (u'\u039f', u'\u03b9'): 3.6330788154204685e-09,
#   (u'&', u'r'): 9.405355087193409e-08,
#   (u'\u2265', u'\u2018'): 0.0,
#   (u'\xa4', u']'): 3.7092972521076107e-09,
#   (u'\u01b7', u'\u03c1'): 0.0,
#   (u'\u03c7', u'r'): 1.5243687337428536e-10,
#   (u'\u02cad', u'\u02c7d'): 0.0,
#   (u'/d', u'\xa5'): 0.0,
#   (u'\u0152', u'\u039e'): 0.0,
#   (u'\u03be', u'\u2265'): 0.0,
#   (u'\u0394', u'\u01dd'): 0.0,
#   (u'\u03c1', u'\u02cad'): 0.0,
#   (u'\u03b4', u'\u03bf'): 2.0706008633340427e-08,
#   (u'\xe8', u'\xbc'): 0.0,
#   (u'\u0130', u'\xb0d'): 0.0,
#   (u'\xae', u'f'): 0.0,
#   (u'\u039f', u'\xbf'): 0.0,
#   (u'\u03a6', u'\u03c9'): 1.4227441514933303e-09,
#   (u'\u02f5d', u'='): 0.0,
#   (u'a', u'}'): 2.642239138487613e-08,
#   (u'\xbe', u'}'): 0.0,
#   (u'\\', u'}'): 6.758034719593318e-09,
#   (u'\u03a5', u'\u039d'): 1.1432765503071402e-09,
#   (u'\u0311d', u'a'): 0.0,
#   (u'\xf7', u'm'): 0.0,
#   (u'=', u'\u02dbd'): 0.0,
#   (u'\xba', u'\u03b8'): 0.0,
#   (u'#', u'\u03c0'): 2.5406145562380896e-11,
#   (u'\u03a5', u','): 4.0649832899809433e-10,
#   (u'd', u'x'): 8.95945054898098e-08,
#   (u'\xb7', u'\u02cad'): 0.0,
#   (u'\xb1', u'\xb8d'): 0.0,
#   (u'\u039d', u'f'): 0.0,
#   (u'\xf9', u')'): 2.520228427595425e-08,
#   (u'\u2264', u'\u014b'): 0.0,
#   (u'\u1e9e', u'\u03c5'): 0.0,
#   (u'\u03b3', u'e'): 2.8733410158207365e-09,
#   (u'\u03b1', u'\u2018'): 0.0,
#   (u'\u018e', u'g'): 0.0,
#   (u'\xc8', u'\u02ddd'): 0.0,
#   (u'f', u'\u201d'): 3.68031849789503e-08,
#   (u'k', u'b'): 2.1137132915850798e-06,
#   (u'\u03a5', u'\u014b'): 0.0,
#   (u'\u03c1', u'a'): 1.5243687337428536e-10,
#   (u'\u2014', u'\xa3'): 0.0,
#   (u'l', u'\u03ba'): 0.0,
#   (u'\u03a9', u'e'): 2.5406145562380896e-11,
#   (u'.d', u'\u03a0'): 0.0,
#   (u'\u0132', u'\u02c7d'): 0.0,
#   (u'<', u'\u03b2'): 7.621843668714268e-11,
#   (u'\xa3', u')'): 4.0840599327106935e-08,
#   (u'\u201e', u'\xa7'): 2.5406145562380896e-11,
#   (u'e', u'z'): 0.0002879617992405935,
#   (u'\u0395', u'\\'): 0.0,
#   (u'\u0391', u'\u03ba'): 1.2703072781190449e-09,
#   (u'\u018e', u'\u039c'): 0.0,
#   (u'q', u't'): 8.813275625981594e-08,
#   (u'\u03b1', u'\u2026'): 0.0,
#   (u'\u0394', u'\u03b2'): 5.081229112476179e-11,
#   (u'\u0391', u'\xa7'): 0.0,
#   (u'\u2018', u'>'): 0.0,
#   (u's', u'\u039b'): 0.0,
#   (u'\u039a', u'\xa8d'): 0.0,
#   (u'k', u'\u03a1'): 0.0,
#   (u'\xa5', u'\u2020'): 0.0,
#   (u'\u039d', u'$'): 0.0,
#   (u'x', u'\xbe'): 0.0,
#   (u'\u03bc', u'\u03bf'): 4.094294438726004e-08,
#   (u'\u2039', u'\u03c4'): 0.0,
#   (u'q', u'v'): 1.4045609438704828e-07,
#   (u'\u0397', u'\u0392'): 2.5406145562380896e-11,
#   (u'%', u'\u03c7'): 0.0,
#   (u'e', u'\u02f5d'): 3.302798923109516e-10,
#   (u'(', u'\xd0'): 7.621843668714268e-11,
#   (u'.d', u'\xaa'): 0.0,
#   (u'\xf7', u'g'): 0.0,
#   (u'\ufeff\xe6', u'\xa3'): 0.0,
#   (u'\\', u'/d'): 0.0,
#   (u'-d', u'\xc0'): 0.0,
#   (u'\u03c7', u's'): 7.621843668714268e-11,
#   (u'\u02c9d', u')'): 1.4944082982489088e-07,
#   (u'k', u'+'): 1.135654706638426e-08,
#   (u'b', u'\u03c1'): 0.0,
#   (u'-d', u'\u0152'): 0.0,
#   (u';', u'\u03c5'): 0.0,
#   (u'\xa2', u'\u03bc'): 0.0,
#   (u'\u01b7', u'\u2260'): 0.0,
#   (u'>', u'a'): 1.3073444141163993e-08,
#   (u'\u2021', u'\u039d'): 0.0,
#   (u'\u03a6', u'o'): 4.319044745604752e-10,
#   (u'm', u'\u03a0'): 0.0,
#   (u'^d', u'\xdf'): 1.3973380059309493e-09,
#   (u'\u03a3', u'\u0133'): 0.0,
#   (u'\u20a9', u'/d'): 0.0,
#   (u'\u2026', u's'): 0.0,
#   (u'\u03c1', u'\u2030'): 0.0,
#   (u'%', u'\u0396'): 0.0,
#   (u'\u2021', u'\u03b1'): 0.0,
#   (u'\u201d', u'\u03c0'): 0.0,
#   (u'k', u'\xe0'): 1.2318040454272456e-08,
#   (u'\xba', u'\xfe'): 0.0,
#   (u'\u03c9', u':'): 1.0162458224952358e-10,
#   (u'\xbb', u'\xa7'): 0.0,
#   (u'c', u'\u2030'): 0.0,
#   (u'\xe9', u'\u03b9'): 0.0,
#   (u'\u017f', u't'): 2.7946760118618987e-09,
#   (u'\xbf', u't'): 7.621843668714268e-11,
#   (u'\xf0', u'\u0311d'): 0.0,
#   (u'^d', u'\u201c'): 0.0,
#   (u'\u039c', u'\u0395'): 1.8038363349290438e-09,
#   (u'\u201d', u'\xa9'): 0.0,
#   (u'|', u'm'): 8.837535889098433e-07,
#   (u'\u03b1', u'\xae'): 0.0,
#   (u'\u014b', u'v'): 5.081229112476179e-11,
#   (u'\ufeff\xe6', u'\xe9'): 0.0,
#   (u'\u03c9', u'b'): 0.0,
#   (u'\xa3', u'*'): 7.621843668714268e-11,
#   (u'\xa5', u'\u03c5'): 0.0,
#   (u'q', u'\u039c'): 0.0,
#   (u'\u02cbd', u'r'): 4.2555293816988e-08,
#   (u'\u2018', u'\u03a1'): 0.0,
#   (u'd', u'n'): 4.8962230367478724e-06,
#   (u'\u03c0', u'space'): 3.45777641104004e-08,
#   (u'\u03b3', u'\xe9'): 0.0,
#   (u'&', u'\u01b7'): 0.0,
#   (u'*', u'\u2018'): 1.676805607117139e-09,
#   (u'\xc0', u'\u2260'): 0.0,
#   (u'\u03a8', u'\u03c6'): 0.0,
#   (u'\u201d', u'\u02c9d'): 0.0,
#   (u'\xd7', u'\u2030'): 0.0,
#   (u'\xa7', u'\xe7'): 2.5406145562380896e-11,
#   (u'\u02d8d', u'\u0399'): 0.0,
#   (u'x', u'!'): 0.0,
#   (u'\xb8d', u'n'): 2.3627715373014237e-09,
#   (u'\u014b', u'\u03c1'): 0.0,
#   (u'e', u'a'): 0.0009434188967244248,
#   (u'\u03c7', u'\u02c7d'): 0.0,
#   (u'\u03b4', u'\xbb'): 0.0,
#   (u'\xb0d', u'y'): 6.097474934971414e-10,
#   (u'\u0394', u'\xb0d'): 0.0,
#   (u'\u2039', u'\xe7'): 0.0,
#   (u'm', u'\xc7'): 0.0,
#   (u'&', u'\xaa'): 0.0,
#   (u'\u221a', u'\u2243'): 0.0,
#   (u'n', u'v'): 0.0008042233542773306,
#   (u'\u017f', u'.'): 2.0324916449904717e-10,
#   (u't', u'\u0311d'): 0.0,
#   (u'z', u'\u0394'): 0.0,
#   (u'/d', u'\u03c3'): 0.0,
#   (u'n', u'\u1e9e'): 0.0,
#   (u'f', u'\u2011'): 2.5406145562380896e-11,
#   (u'$', u'\u2014'): 0.0,
#   (u'p', u'-'): 4.761170912491598e-06,
#   (u'u', u'\u0131'): 2.7946760118618985e-10,
#   (u'<', u'\xbb'): 0.0,
#   (u'\u0398', u'\u03b6'): 0.0,
#   (u'\u0392', u'>'): 0.0,
#   (u':', u'{'): 3.492098165163607e-07,
#   (u'\xaa', u'\xaa'): 0.0,
#   (u'\u203a', u'\u03b9'): 0.0,
#   (u'\u02cbd', u'\u039a'): 0.0,
#   (u'i', u'\xe8'): 0.0008164077891335595,
#   (u'x', u':'): 2.1965137546556384e-06,
#   (u'\u0311d', u'\xab'): 0.0,
#   (u'\u03ba', u'\u03be'): 5.081229112476179e-11,
#   (u'k', u'\u0397'): 0.0,
#   (u'\u039f', u'f'): 0.0,
#   (u'@', u'\u2260'): 0.0,
#   (u'\u03bc', u'~d'): 0.0,
#   (u')', u'\xf7'): 1.2703072781190449e-10,
#   (u'\xaa', u'u'): 0.0,
#   (u'|', u'\xa2'): 1.7784301893666626e-10,
#   (u'j', u'\xae'): 0.0,
#   (u'\xd0', u'\u03b1'): 0.0,
#   (u'\u03b82', u'a'): 0.0,
#   (u'\u03b9', u'\u0130'): 0.0,
#   (u':', u'\u02c7d'): 0.0,
#   (u']', u't'): 3.6907130496774394e-09,
#   (u'k', u'\u0395'): 0.0,
#   (u'\u03a0', u'\u039d'): 1.1432765503071402e-09,
#   (u'\u03c8', u'\u03c4'): 1.0162458224952358e-10,
#   (u'\u02c7d', u'\xa1'): 5.081229112476179e-11,
#   (u'\u03b7', u'~d'): 0.0,
#   (u'&', u'\u03bc'): 0.0,
#   (u'g', u'$'): 2.4643961195509468e-09,
#   (u'\u014b', u'\xa8d'): 0.0,
#   (u'~d', u'k'): 2.8963005941114218e-09,
#   (u'\u0292', u'e'): 4.573106201228562e-10,
#   (u'm', u'\xb0'): 3.423774581190063e-08,
#   (u'\u03b9', u','): 8.085976231969334e-09,
#   (u'\u03b1', u'\u0292'): 0.0,
#   (u'\u01b7', u'\xde'): 0.0,
#   (u'\xf9', u'\xba'): 0.0,
#   (u'\u03c4', u'\xa2'): 0.0,
#   (u'\xa2', u'n'): 2.5406145562380896e-11,
#   (u'\u03a3', u'\u02c9d'): 0.0,
#   (u'\u0393', u'\xe8'): 0.0,
#   (u'\u221a', u'\u0394'): 5.081229112476179e-11,
#   (u'\u0311d', u'\u201d'): 0.0,
#   (u'\u201e', u'\u03a4'): 0.0,
#   (u'\u2260', u'\u2265'): 0.0,
#   (u'#', u'\xab'): 0.0,
#   (u'^d', u'?'): 2.385800172792346e-08,
#   (u'\u03a4', u'.'): 6.097474934971414e-10,
#   (u'\u2021', u'k'): 0.0,
#   (u'\u201c', u'\u02d8d'): 0.0,
#   (u'\u0152', u'+'): 0.0,
#   (u'j', u'\u03c7'): 2.5406145562380896e-11,
#   (u'<', u'~d'): 0.0,
#   (u'\u03b6', u'\u0397'): 0.0,
#   (u'\u0396', u'|'): 0.0,
#   (u'/d', u'\u2020'): 0.0,
#   (u'\u03b5', u'n'): 9.400273858080932e-10,
#   (u'\u0392', u'\u03c0'): 0.0,
#   (u'.d', u'\u03c8'): 0.0,
#   (u',', u'\u0394'): 1.7784301893666626e-10,
#   (u'\u03b9', u'\u1e9e'): 0.0,
#   (u'\u0393', u'\xbd'): 0.0,
#   (u'c', u'\u03b1'): 2.7946760118618985e-10,
#   (u'\u03b4', u'\u2021'): 0.0,
#   (u'\xa1', u'\u2019'): 0.0,
#   (u'\u221e', u'\u0131'): 0.0,
#   (u'\u2014', u'\u02c9d'): 0.0,
#   (u'\u2018', u'\u03be'): 0.0,
#   (u'\xa4', u'\u03bb'): 0.0,
#   (u'd', u'\xe0'): 7.513102739510604e-08,
#   (u'\u02f5d', u'i'): 2.5406145562380896e-11,
#   (u'\xb0', u'\xd0'): 9.21443183377922e-10,
#   (u'h', u'\u02cbd'): 0.0,
#   (u')', u'y'): 0.0,
#   (u'\u017f', u'\u03b4'): 0.0,
#   (u'@', u'\u02dbd'): 0.0,
#   (u'\u201a', u'\u2013'): 0.0,
#   (u')', u'\u03c8'): 5.081229112476179e-11,
#   (u'\u03c6', u'\u0292'): 0.0,
#   (u'r', u'&'): 3.559529133941509e-07,
#   (u'/', u'\u0395'): 3.048737467485707e-10,
#   (u',d', u'%'): 0.0,
#   (u'/d', u'\u03b1'): 0.0,
#   (u'\u03a7', u'\u03a5'): 3.5568603787333253e-10,
#   (u'(', u'\u03c1'): 2.2865531006142807e-09,
#   (u'}', u'\u039f'): 0.0,
#   (u'\u03b5', u'\u0399'): 0.0,
#   (u'\u2264', u'\u0132'): 0.0,
#   (u'\u018e', u'^d'): 0.0,
#   (u'\xc6', u'\xbf'): 0.0,
#   (u'b', u'\u2026'): 1.8653207377827266e-08,
#   (u'g', u'\u0130'): 0.0,
#   (u'\xa9', u'$'): 0.0,
#   (u'\u0131', u'f'): 5.9450380615971294e-09,
#   (u'\u2243', u'\xbc'): 0.0,
#   (u'\u0396', u'q'): 0.0,
#   (u'\u014b', u'\u02cbd'): 0.0,
#   (u'\xdf', u'\xa9'): 0.0,
#   (u'\u0131', u'\u203a'): 5.081229112476179e-11,
#   (u'\u02dbd', u'\xae'): 0.0,
#   (u'\u03be', u'\u039f'): 0.0,
#   (u'\u0399', u'a'): 2.5406145562380896e-11,
#   (u'\u0395', u'\u2030'): 0.0,
#   (u'\u2019', u'\u03b5'): 1.0162458224952358e-10,
#   (u'\u2021', u'\u0311d'): 0.0,
#   (u'\xb7', u'\u2039'): 0.0,
#   (u'\u014a', u'd'): 0.0,
#   (u'\xdf', u',d'): 0.0,
#   (u'\u03b8', u'\u039b'): 0.0,
#   (u'{', u'\u03c9'): 5.081229112476179e-11,
#   (u'\xb7', u'\xbc'): 0.0,
#   (u'\u03a6', u'\u014a'): 0.0,
#   (u'\u02cad', u'\u03a1'): 2.5406145562380896e-11,
#   (u'\u03bd', u'y'): 2.5406145562380896e-11,
#   (u'\u0391', u'\u201e'): 0.0,
#   (u'+', u'f'): 2.2266683067897365e-08,
#   (u'^d', u'\xbd'): 2.5406145562380896e-11,
#   (u'.', u'!'): 2.4748679084588215e-07,
#   (u'\u039d', u'\xb7'): 0.0,
#   (u'\u1e9e', u'\xf0'): 0.0,
#   (u'<', u'\u01b7'): 0.0,
#   (u',d', u'\u0397'): 0.0,
#   (u'\u0393', u'\u2020'): 0.0,
#   (u'\u2019', u'\u03b7'): 0.0,
#   (u'\xa2', u'\u203a'): 0.0,
#   (u'\xe7', u'e'): 3.824237118689672e-07,
#   (u'\u03bb', u'\u03b4'): 6.097474934971414e-10,
#   (u'\u03bc', u'\u2026'): 0.0,
#   (u'\u03c6', u'\u03bb'): 8.129966579961887e-10,
#   (u'_d', u'\u02cad'): 0.0,
#   (u'\xab', u'\xa7'): 0.0,
#   (u'\xaa', u'\xbd'): 0.0,
#   (u'\xa9', u'\u1e9e'): 0.0,
#   (u'\u018e', u'*'): 0.0,
#   (u'h', u'\xb1'): 2.5406145562380896e-11,
#   (u'\xb1', u'o'): 2.5406145562380897e-10,
#   (u'j', u'\u0393'): 0.0,
#   (u'\u2011', u'\u03b82'): 0.0,
#   (u']', u'\u03b8'): 0.0,
#   (u'\xd0', u'\u2030'): 0.0,
#   (u'l', u'm'): 8.821006011535308e-05,
#   (u'\xbb', u'\u2020'): 0.0,
#   (u'\u0396', u'\u01dd'): 0.0,
#   (u'\xb8d', u'\xa1'): 0.0,
#   (u'\u014a', u'\u018e'): 0.0,
#   (u'\xe9', u'\u03ba'): 0.0,
#   (u'\u039d', u'\u03b82'): 0.0,
#   (u'\u03a5', u'\u014a'): 0.0,
#   (u'\u2011', u'-'): 2.5406145562380896e-11,
#   (u'\u03a7', u'\u0152'): 0.0,
#   (u'\xae', u'_d'): 0.0,
#   (u'\u0130', u'\u20a9'): 0.0,
#   (u'h', u'\u039a'): 0.0,
#   (u'|', u'\u0292'): 5.081229112476179e-11,
#   (u'j', u'f'): 1.2480040297657997e-07,
#   (u'\u02c7d', u'\u03a5'): 0.0,
#   (u':', u'r'): 2.229632429781014e-08,
#   (u'[', u'\u0130'): 0.0,
#   (u'\u2264', u'\u039a'): 0.0,
#   (u'-', u'\xbc'): 0.0,
#   (u'#', u'\u02d8d'): 0.0,
#   (u'\u01b7', u'\u03a1'): 0.0,
#   (u'\xbe', u'\u03a0'): 0.0,
#   (u'#', u'\u0132'): 0.0,
#   (u'\xbc', u'\xa9'): 0.0,
#   (u'\u03b3', u'\u03ba'): 4.623918492353323e-09,
#   (u'{', u'\xbe'): 0.0,
#   (u'\xbe', u'\xb7'): 7.621843668714268e-11,
#   (u'\u0398', u'='): 2.5406145562380896e-11,
#   (u'\u03a8', u'\u03c5'): 3.3027989231095165e-10,
#   (u'-d', u'\xab'): 0.0,
#   (u'_d', u'\u039e'): 0.0,
#   (u'y', u'\u221e'): 2.5406145562380896e-11,
#   (u'b', u'\u03b82'): 0.0,
#   (u'\u02c9d', u'\xbd'): 0.0,
#   (u'\u0396', u'\xa4'): 0.0,
#   (u'\u0131', u'\u201e'): 0.0,
#   (u'[', u'\u02c9d'): 0.0,
#   (u'\u03b82', u'.d'): 0.0,
#   (u'\u03be', u'.'): 3.5568603787333253e-10,
#   (u'\u0399', u'\xbb'): 0.0,
#   (u'd', u'\u0398'): 0.0,
#   (u'\xc9', u'\u0152'): 2.5406145562380896e-11,
#   (u'\xa4', u'{'): 0.0,
#   (u'f', u'\xb0d'): 0.0,
#   (u'\xf7', u'\xa1'): 5.081229112476179e-11,
#   (u'\xaa', u'f'): 0.0,
#   (u'\xa8d', u'\u2020'): 0.0,
#   (u'\u03ba', u'\u203a'): 0.0,
#   (u'\u03b9', u'\u2026'): 5.081229112476179e-11,
#   (u'(', u'\u039c'): 6.478567118407128e-09,
#   (u'\u2020', u'm'): 1.2703072781190449e-10,
#   (u'l', u'\u03c9'): 0.0,
#   (u'\u03c8', u'\xbe'): 0.0,
#   (u'\xbf', u'\u2026'): 0.0,
#   (u'\u03c5', u'\xa5'): 0.0,
#   (u'\xc6', u'a'): 2.5406145562380896e-11,
#   (u'^d', u'\u02c9d'): 0.0,
#   (u'h', u'\u01dd'): 5.081229112476179e-11,
#   (u'\u039e', u'm'): 0.0,
#   (u'/d', u'\u2013'): 0.0,
#   (u'\u02c7d', u'\u039f'): 0.0,
#   (u'$', u'?'): 2.1223539679420333e-09,
#   (u'\u03b2', u'\u03b9'): 6.148287226096177e-09,
#   (u'\xae', u'\u0398'): 0.0,
#   (u',', u'/'): 8.655184743857261e-08,
#   (u'\u02ddd', u'\\'): 0.0,
#   (u'\xc0', u'\u2011'): 0.0,
#   (u'\u014a', u'\u03b6'): 0.0,
#   (u',', u'\u03c9'): 3.048737467485707e-10,
#   (u'\u03a8', u'\u03b2'): 0.0,
#   (u'\u039a', u']'): 0.0,
#   (u'\u201a', u'w'): 2.5406145562380896e-11,
#   (u'\u20a9', u'\u03a5'): 0.0,
#   (u'\u03be', u'*'): 0.0,
#   (u'm', u'\u2026'): 9.496718253727328e-08,
#   (u'\u20a9', u'\u039e'): 0.0,
#   (u's', u'\u03bb'): 0.0,
#   (u'space', u'q'): 0.003242678702351431,
#   (u'\u0395', u'\u03b1'): 5.081229112476179e-11,
#   (u'\u0131', u'?'): 2.5406145562380897e-10,
#   (u'\u02dbd', u'\u02ddd'): 0.0,
#   (u'\u0133', u'z'): 0.0,
#   (u'\u017f', u'j'): 0.0,
#   (u'\u03b7', u'&'): 0.0,
#   (u'@', u'\xe8'): 0.0,
#   (u'\xa8d', u'e'): 4.601680709196678e-06,
#   (u'\u02d9d', u'\u014b'): 0.0,
#   (u'\u0394', u'\u03a7'): 1.0162458224952358e-10,
#   (u'\u01b7', u'\u03bb'): 0.0,
#   (u'\u02cbd', u'\u02cad'): 0.0,
#   (u'\u02ddd', u'\xe0'): 0.0,
#   (u'}', u'\u0394'): 0.0,
#   (u'\u1e9e', u'\u03ba'): 0.0,
#   (u'\xba', u'\u02ddd'): 0.0,
#   (u'\u03c1', u'<'): 0.0,
#   (u'n', u'\xb0'): 4.619072278216942e-05,
#   (u'\u2014', u'\u0398'): 0.0,
#   (u'\u03a3', u'\u0153'): 0.0,
#   (u'\xe9', u'\u2020'): 2.286553100614281e-10,
#   (u'\u039d', u'\xa9'): 0.0,
#   (u'\u039b', u'\u03c4'): 0.0,
#   (u'\u03bc', u'\u02d8d'): 0.0,
#   (u'\u03ba', u'\u201e'): 0.0,
#   (u'q', u'\u03b82'): 0.0,
#   (u'.', u'.'): 0.0007703341907840175,
#   (u'\u0393', u'-d'): 0.0,
#   (u'\xc0', u'\u03b82'): 0.0,
#   (u'\u03b82', u'\xbb'): 0.0,
#   (u']', u'\u02ddd'): 0.0,
#   (u'\u03c6', u'n'): 1.0162458224952358e-10,
#   (u'h', u'\u03b5'): 2.5406145562380896e-11,
#   (u'\xf7', u'\xd7'): 0.0,
#   (u'\u017f', u'\u03a9'): 0.0,
#   (u'\u02cad', u'\u2018'): 1.5243687337428538e-09,
#   (u'\u2264', u'\u02dbd'): 0.0,
#   (u'q', u'\u0393'): 0.0,
#   (u'\u03c0', u'\u1e9e'): 0.0,
#   (u'\xd0', u'\u2013'): 0.0,
#   (u'\u201c', u'\u02c7d'): 0.0,
#   (u'\u03a6', u'\xf9'): 0.0,
#   (u'\u0132', u'z'): 0.0,
#   (u'b', u'\xbe'): 0.0,
#   (u'd', u'\u018e'): 0.0,
#   (u'\u1e9e', u'\u02cad'): 0.0,
#   (u'\xc0', u'\xe8'): 0.0,
#   (u'\u03c9', u'\u0130'): 0.0,
#   (u'\u2260', u'\u201e'): 0.0,
#   (u'@', u'.d'): 0.0,
#   (u'\u0152', u'\u02c9d'): 0.0,
#   (u'\xa2', u'@'): 0.0,
#   (u'%', u'\xba'): 0.0,
#   (u',d', u'w'): 0.0,
#   (u'\u2265', u'\u0394'): 0.0,
#   (u'\u2026', u'\xbc'): 0.0,
#   ...})

# %%
p_single = pd.read_csv("input/frequency_letters_scenario2.txt", sep=" ", encoding="utf-8", index_col=None, quoting=3, names={u'letter', u'frequency'})
#p_single = p_single.to_dict()[u'frequency']

# %%
letters = get_letters()
all_chars = characters('input/characters_scenario2.txt')
all_chars = letters + all_chars + get_fixed_characters()
letter_file = "input/resources/frequency_letters_mathieu.txt"
p_single_all = pd.read_csv(letter_file, sep=" ", encoding="utf-8", index_col=0, quoting=3)
p_single_all = p_single_all.to_dict()[u'frequency']
p_single = {c:0 for c in all_chars}

# %%
c = u"."
v = p_single_all[c]
c = correct_diacritic(c) #in case this is a wrong form of a "d" annotated diacritic
if c in p_single.keys():
    p_single[c] += v
else:
    c_dec = decompose(c)
    if len(c_dec) > 1:
        #it's a composed character, take it apart and add the frequency to the frequency of its components
        if c_dec[1] in unicode_diacritic.keys():
            diacritic = unicode_diacritic[c_dec[1]]

            if diacritic in p_single.keys():
                p_single[diacritic] += v
        letter = c_dec[0]
        if letter in p_single.keys():
            p_single[letter] += v
    elif c in diacritic_unicode.keys():
        #it's a single form of the diacritic mark, e.g. ~. Add frequency to diacritic and to space
        diacritic = unicode_diacritic[diacritic_unicode[c]]
        p_single[diacritic] += v
        p_single["space"] += v
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-c504c610913f> in <module>()
#      22         p_single["space"] += v
#      23
# ---> 24 p_single[c]
#
# KeyError: u'.'

# %%
p_single
# Out:
# {u'#': 0,
#  u'$': 0,
#  u'%': 0,
#  u'&': 0,
#  u'(': 0,
#  u')': 0,
#  u'*': 0,
#  u'+': 0,
#  u',d': 0,
#  u'-': 0,
#  u'-d': 0,
#  u'.d': 0.020935583161274286,
#  u'/d': 0,
#  u'<': 0,
#  u'=': 0,
#  u'>': 0,
#  u'@': 0,
#  u'[': 0,
#  u'\\': 0,
#  u']': 0,
#  u'^d': 0,
#  u'_': 0,
#  u'_d': 0,
#  u'a': 0,
#  u'b': 0,
#  u'c': 0,
#  u'd': 0,
#  u'e': 0,
#  u'f': 0,
#  u'g': 0,
#  u'h': 0,
#  u'i': 0,
#  u'j': 0,
#  u'k': 0,
#  u'l': 0,
#  u'm': 0,
#  u'n': 0,
#  u'o': 0,
#  u'p': 0,
#  u'q': 0,
#  u'r': 0,
#  u's': 0,
#  u'space': 0.020935583161274286,
#  u't': 0,
#  u'u': 0,
#  u'v': 0,
#  u'w': 0,
#  u'x': 0,
#  u'y': 0,
#  u'z': 0,
#  u'{': 0,
#  u'|': 0,
#  u'}': 0,
#  u'~d': 0,
#  u'\xa1': 0,
#  u'\xa2': 0,
#  u'\xa3': 0,
#  u'\xa4': 0,
#  u'\xa5': 0,
#  u'\xa7': 0,
#  u'\xa8d': 0,
#  u'\xa9': 0,
#  u'\xaa': 0,
#  u'\xab': 0,
#  u'\xae': 0,
#  u'\xb0': 0,
#  u'\xb0d': 0,
#  u'\xb1': 0,
#  u'\xb4d': 0,
#  u'\xb7': 0,
#  u'\xb8d': 0,
#  u'\xba': 0,
#  u'\xbb': 0,
#  u'\xbc': 0,
#  u'\xbd': 0,
#  u'\xbe': 0,
#  u'\xbf': 0,
#  u'\xc0': 0,
#  u'\xc6': 0,
#  u'\xc7': 0,
#  u'\xc8': 0,
#  u'\xc9': 0,
#  u'\xd0': 0,
#  u'\xd7': 0,
#  u'\xde': 0,
#  u'\xdf': 0,
#  u'\xe0': 0,
#  u'\xe7': 0,
#  u'\xe8': 0,
#  u'\xe9': 0,
#  u'\xf0': 0,
#  u'\xf7': 0,
#  u'\xf9': 0,
#  u'\xfe': 0,
#  u'\u0130': 0,
#  u'\u0131': 0,
#  u'\u0132': 0,
#  u'\u0133': 0,
#  u'\u014a': 0,
#  u'\u014b': 0,
#  u'\u0152': 0,
#  u'\u0153': 0,
#  u'\u017f': 0,
#  u'\u018e': 0,
#  u'\u01b7': 0,
#  u'\u01dd': 0,
#  u'\u0292': 0,
#  u'\u02c7d': 0,
#  u'\u02c9d': 0,
#  u'\u02cbd': 0,
#  u'\u02d8d': 0,
#  u'\u02d9d': 0,
#  u'\u02dbd': 0,
#  u'\u02ddd': 0,
#  u'\u02f5d': 0,
#  u'\u0311d': 0,
#  u'\u0391': 0,
#  u'\u0392': 0,
#  u'\u0393': 0,
#  u'\u0394': 0,
#  u'\u0395': 0,
#  u'\u0396': 0,
#  u'\u0397': 0,
#  u'\u0398': 0,
#  u'\u0399': 0,
#  u'\u039a': 0,
#  u'\u039b': 0,
#  u'\u039c': 0,
#  u'\u039d': 0,
#  u'\u039e': 0,
#  u'\u039f': 0,
#  u'\u03a0': 0,
#  u'\u03a1': 0,
#  u'\u03a3': 0,
#  u'\u03a4': 0,
#  u'\u03a5': 0,
#  u'\u03a6': 0,
#  u'\u03a7': 0,
#  u'\u03a8': 0,
#  u'\u03a9': 0,
#  u'\u03b1': 0,
#  u'\u03b2': 0,
#  u'\u03b3': 0,
#  u'\u03b4': 0,
#  u'\u03b5': 0,
#  u'\u03b6': 0,
#  u'\u03b7': 0,
#  u'\u03b8': 0,
#  u'\u03b82': 0,
#  u'\u03b9': 0,
#  u'\u03ba': 0,
#  u'\u03bb': 0,
#  u'\u03bc': 0,
#  u'\u03bd': 0,
#  u'\u03be': 0,
#  u'\u03bf': 0,
#  u'\u03c0': 0,
#  u'\u03c1': 0,
#  u'\u03c3': 0,
#  u'\u03c4': 0,
#  u'\u03c5': 0,
#  u'\u03c6': 0,
#  u'\u03c7': 0,
#  u'\u03c8': 0,
#  u'\u03c9': 0,
#  u'\u1e9e': 0,
#  u'\u2011': 0,
#  u'\u2013': 0,
#  u'\u2014': 0,
#  u'\u2018': 0,
#  u'\u2019': 0,
#  u'\u201a': 0,
#  u'\u201c': 0,
#  u'\u201d': 0,
#  u'\u201e': 0,
#  u'\u2020': 0,
#  u'\u2021': 0,
#  u'\u2026': 0,
#  u'\u2030': 0,
#  u'\u2039': 0,
#  u'\u203a': 0,
#  u'\u20a9': 0,
#  u'\u221a': 0,
#  u'\u221e': 0,
#  u'\u2243': 0,
#  u'\u2260': 0,
#  u'\u2264': 0,
#  u'\u2265': 0,
#  u'\ufeff\xe6': 0}

# %%
from plotting import *
mapping = {1:"a"}
path = "test.csv"
log_mapping(mapping, path)
# Out:
# C:\Users\feita1\Python_Anaconda\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
from test_model import *
create_dummy_values_performance_ergonomics_probability(randomize=False)
# Out:
# read in: characters, keyslots and letters

# %%
# Out:
# 0.002072

# %%
# Out:
# u'(,, ~)'

# %%
# Out:
# {(u'!', u'\xa1'): 1.0,
#  (u'%', u'\u2030'): 1.0,
#  (u"'", u'"'): 1.0,
#  (u'(', u')'): 1.0,
#  (u'+', u'\xb1'): 1.0,
#  (u',', u';'): 1.0,
#  (u'-', u'_'): 1.0,
#  (u'.', u':'): 1.0,
#  (u'/', u'\\'): 1.0,
#  (u'<', u'>'): 1.0,
#  (u'<', u'\u2264'): 1.0,
#  (u'=', u'\u2260'): 1.0,
#  (u'>', u'\u2265'): 1.0,
#  (u'?', u'\xbf'): 1.0,
#  (u'[', u']'): 1.0,
#  (u'`d', u'\xe0'): 1.0,
#  (u'{', u'}'): 1.0,
#  (u'|', u'\xa6'): 1.0,
#  (u'~d', u'~'): 1.0,
#  (u'\xab', u'\xbb'): 1.0,
#  (u'\xb4d', u'`d'): 1.0,
#  (u'\xb4d', u'\xe9'): 1.0,
#  (u'\xb8d', u'\xe7'): 1.0,
#  (u'\xe0', u'\xc0'): 1.0,
#  (u'\xe6', u'\xc6'): 1.0,
#  (u'\xe9', u'\xc9'): 1.0,
#  (u'\xf8', u'\xd8'): 1.0,
#  (u'\u0152', u'\u0153'): 1.0,
#  (u'\u02ddd', u'"'): 1.0,
#  (u'\u20ac', u'$'): 1.0,
#  (u'\u20ac', u'\xa3'): 1.0,
#  (u'\u20ac', u'\xa4'): 1.0}

# %%
def _is_composed_of(deadkey, character):
    """
        checks if the given character is a composed character and if it is composed with the given deadkey
    """
    if len(character)>1:
        #has multiple characters in it, check if the deadkey is somehwere in there
        for c in character:
            res = _is_composed_of(deadkey,c)
            if res:
                return res
    if unicodedata.decomposition(character) == "":
        return 0
    else:
        deadkey_code = unicodedata.decomposition(deadkey)[-4:]
        character_code = unicodedata.decomposition(character)[-4:]
        return deadkey_code == character_code
_is_composed_of(u"ˆ", u"â")
# Out:
# False

# %%
def decompose(c):
    try:
        #print c
        c_d = unicodedata.normalize('NFKD', c)
        #special_char_list = {"^": "0302", "~":"0303", "`":"0300"}
        special_char_list = {}
        for i in range(0,len(c_d)):
            if c_d[i] in special_char_list:
                c_d[i] = special_char_list[c_d[i]]
                
        return c_d
    except:
        return c

# %%
print(decompose(u"ˊ"))
# Out:
# ˊ
# É

# %%
unicodedata.decomposition(u"è")
# Out:
# '0065 0300'

# %%
unicodedata.decomposition(u"ˊ")
# Out:
# ''

# %%
unicodedata.decomposition(u"ˊ")
# Out:
# ''

# %%
u"\0301"
# Out:
# u'\x181'

# %%
u"ˊ"
# Out:
# u'\u02ca'

# %%
u"´"
# Out:
# u'\xb4'

# %%
# Out:
#   File "<ipython-input-67-47d5722d1bfb>", line 1
#     ̲
#     ^
# SyntaxError: invalid syntax

# %%
unicodedata.normalize('NFKD', u"´d")
# Out:
# u' \u0301d'

# %%
unicodedata.normalize('NFKD', u"ľ")
# Out:
# u'l\u030c'

# %%
c[1]
# Out:
# u'\u0303'

# %%
diacritic_unicode = {u"^": u"\u0302", u"ˆ": u"\0302",
                     u"¨": u"\u0308",
                     u"~": u"\u0303", u"˜": u"\0303", 
                     u"˘": u"\u0306",
                     u"ˇ": u"\030c",
                     u"̑": u"\0311",
                     u"ˋ": u"\0300", u"`": u"\0300", 
                     u"ˊ": u"\0301", 
                     u"ˉ": u"\0304", 
                     u"_": u"\0331", u"̲":u"\0331",
                     u"˙": u"\0307",
                     u".": u"\0323",
                     u"°": u"\030a",
                     u"˝": u"\030b",
                     u"˵": u"\030f", u"̏": u"\030f",                     
                     u"¸": u"\0327",
                     u"˛": u"\0328",
                     u",": u"\0326", u"̦": u"\0326", 
                     u"-": u"\0335", u"̵": u"\0335",
                     u"/": u"\0337", u"̷": u"\0337"
                    }

# %%
unicode_diacritic = {u"\0302": u"^",
                     u"\0308": u"¨",
                     u"\0303": u"~",
                     u"\0306": u"˘",
                     u"\030c": u"ˇ",
                     u"\0311": u"̑ ",
                     u"\0300": u"ˋ",
                     u"\0301": u"ˊ",
                     u"\0304": u"ˉ",
                     u"\0331": u"_",
                     u"\0307": u"˙",
                     u"\0323": u".",
                     u"\030a": u"°",
                     u"\030b": u"˝",
                     u"\030f": u"˵",              
                     u"\0327": u"¸",
                     u"\0328": u"˛",
                     u"\0326": u",",
                     u"\0335": u"-",
                     u"\0337": u"/"
                    }

# %%
a = ["a", "b"]
a.remove("a")

# %%
if a: 0 else: 1
# Out:
#   File "<ipython-input-85-680cb9139289>", line 1
#     if a: 0 else: 1
#                ^
# SyntaxError: invalid syntax
