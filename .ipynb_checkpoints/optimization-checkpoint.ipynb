# %%
characters = get_characters()
u'ǝ' in characters
# Out:
# True

# %%
from objectives import * 
from read_input import *
from plotting import *
from reformulation_input import *
from evaluate_reformualtion_solution import * 
from optimize import *

PYTHONIOENCODING="utf-8"

'''
Defines weights and level costs and creates the input file for reformulating the problem
'''

w_p, w_a, w_f, w_e = [1.0,0.0,0.0,0.0]
corpus_weights = {'formal':0.5, 'twitter':0.3, 'code':0.2}

set_scenario_files("scenario3a")

#create_reformulation_input(w_p, w_a, w_f, w_e, corpus_weights, "scenario3", quadratic=1)

mapping = solve_the_keyboard_Problem(w_p, w_a, w_f, w_e, corpus_weights, quadratic=0, capitalization_constraints=0, name="3a_perf")
mapping = solve_the_keyboard_Problem(w_p, w_a, w_f, w_e, corpus_weights, quadratic=0, capitalization_constraints=1, name="3a_perf_capital")
#model = optimize_reformulation("reformulation\\reformulation_scenario3_ass.lp")
w_p, w_a, w_f, w_e = [0.25,0.25,0.25,0.25]
mapping = solve_the_keyboard_Problem(w_p, w_a, w_f, w_e, corpus_weights, quadratic=0, capitalization_constraints=0, name="3a_even")
mapping = solve_the_keyboard_Problem(w_p, w_a, w_f, w_e, corpus_weights, quadratic=0, capitalization_constraints=1, name="3a_even_capital")
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# set objective
# set constraints
# Warning: variable name ":_to_B00" has a colon
# Warning: constraint name ":_mapped_once" has a colon
# Warning: to let Gurobi read it back, use rlp format
# optimizing with linear terms only...
# Optimize a model with 246 rows, 15093 columns and 30186 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [4e-09, 1e+00]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+00]
# Found incumbent soln at node 0 objective 4.06712976317
# Found heuristic solution: objective 4.06713
# Presolve time: 0.08s
# Presolved: 246 rows, 15093 columns, 30186 nonzeros
# Variable types: 0 continuous, 15093 integer (15093 binary)
#
# Root relaxation: objective 2.336065e+00, 1151 iterations, 0.12 seconds
# Found incumbent soln at node 0 objective 2.33606515013
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.3360652    2.33607  0.00%     -    0s
#
# Explored 0 nodes (1151 simplex iterations) in 0.44 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.336065150128e+00, best bound 2.336065150128e+00, gap 0.0%
# done
# Performance: 2.336
# Association: 4.743
# Familiarity: 2.899
# Ergonomics: 3.195
# ! to E08
# # to C11
# $ to B04_Alt
# % to B00_Alt
# & to C01_Alt
# ( to E06
# ) to E05
# * to B09_Shift
# + to B10_Alt
# , to E00
# ,d to B09
# - to E01
# -d to C12
# . to E03
# .d to B08
# / to B00
# /d to B07
# : to B10
# ; to E02
# < to B08_Alt
# = to E07
# > to C11_Alt
# ? to E12_Shift
# @ to E12
# [ to E01_Alt
# \ to E11_Shift
# ] to D11_Shift
# ^d to D12
# _ to E10
# _d to C12_Shift
# { to D11
# | to C11_Shift
# } to B00_Shift
# ~d to C02_Alt
# ¡ to D11_Alt_Shift
# ¢ to E12_Alt_Shift
# £ to B05_Alt
# ¤ to D05_Alt
# ¥ to B02_Alt_Shift
# § to E05_Alt
# ¨d to B01_Alt
# © to D12_Alt
# ª to C02_Alt_Shift
# « to B08_Shift
# ® to D02_Alt
# ° to C03_Alt
# °d to E11_Alt
# ± to C12_Alt
# ´d to E03_Alt
# · to E02_Alt
# ¸d to B03_Alt
# º to E05_Alt_Shift
# » to B10_Shift
# ¼ to E07_Alt_Shift
# ½ to C07_Alt
# ¾ to C04_Alt
# ¿ to E07_Alt
# Æ to D08_Alt
# Ð to B03_Alt_Shift
# × to D11_Alt
# Þ to C03_Alt_Shift
# ß to C10_Alt
# à to E11
# æ to D04_Alt
# ç to D06_Alt
# è to E09
# é to E04
# ð to E06_Alt
# ÷ to B09_Alt_Shift
# ù to B09_Alt
# þ to D01_Alt_Shift
# İ to B00_Alt_Shift
# ı to E12_Alt
# Ĳ to E08_Alt_Shift
# ĳ to D04_Alt_Shift
# Ŋ to E09_Alt_Shift
# ŋ to E06_Alt_Shift
# Œ to E01_Alt_Shift
# œ to E08_Alt
# ſ to B08_Alt_Shift
# Ə to E02_Alt_Shift
# Ʒ to C08_Alt_Shift
# ə to B07_Alt_Shift
# ʒ to B01_Alt_Shift
# ˇd to D07_Alt
# ˉd to E04_Alt
# ˋd to E00_Shift
# ˘d to D09_Alt_Shift
# ˙d to D10_Alt
# ˛d to B02_Alt
# ˝d to E04_Alt_Shift
# ˵d to B05_Alt_Shift
# ̑d to D08_Alt_Shift
# θ2 to D05_Alt_Shift
# ẞ to E11_Alt_Shift
# ‑ to B07_Alt
# – to D12_Shift
# — to B07_Shift
# ‘ to C08_Alt
# ’ to C06_Alt
# ‚ to C06_Alt_Shift
# “ to E09_Alt
# ” to E00_Alt
# „ to C09_Alt
# † to B06_Alt
# ‡ to D06_Alt_Shift
# … to D01_Alt
# ‰ to C05_Alt
# ‹ to B10_Alt_Shift
# › to D09_Alt
# ₩ to B04_Alt_Shift
# √ to C09_Alt_Shift
# ∞ to E10_Alt
# ≃ to C10_Alt_Shift
# ≠ to D10_Alt_Shift
# ≤ to D07_Alt_Shift
# ≥ to C11_Alt_Shift
# Obj: 2.33607
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# ·: 0.555555
# C:\Users\feita1\Python_Anaconda\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# plotting.py:226: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if not objective=="":
# @: 0.314277
# ß: 0.253268
# ç: 0.119552
# ₩: 0.003068
# #: 0.028235
# √: 0.113860
# ı: 0.147987
# à: 0.522863
# è: 0.593208
# ð: 0.076764
# ¥: 0.011652
# ©: 0.230997
# é: 0.188288
# ù: 0.127499
# ʒ: 0.008281
# ~d: 0.168211
': u'E08', u'\xa2': u'E12_Alt_Shift', u'%': u'B00_Alt', u')': u'E05', u'\u201d': u'E00_Alt', u'\xaa': u'C02_Alt_Shift', u'-': u'E01', u'\xae': u'D02_Alt', u'\u0133': u'D04_Alt_Shift', u'\u02dbd': u'B02_Alt', u'\u2039': u'B10_Alt_Shift', u'\xba': u'E05_Alt_Shift', u'=': u'E07', u'\xbe': u'C04_Alt', u'\u2021': u'D06_Alt_Shift', u'\xc6': u'D08_Alt', u'\u014b': u'E06_Alt_Shift', u'\u0153': u'E08_Alt', u'\u0259': u'B07_Alt_Shift', u']': u'D11_Shift', u'\xde': u'C03_Alt_Shift', u',d': u'B09', u'\u2265': u'C11_Alt_Shift', u'\xe6': u'D04_Alt', u'^d': u'D12', u'\u02f5d': u'B05_Alt_Shift', u'}': u'B00_Shift', u'\u017f': u'B08_Alt_Shift', u'\xfe': u'D01_Alt_Shift'}
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# set objective
# Adding capitalization constraints
# à, À, not in character set
# â, Â, not in character set
# ç, Ç, not in character set
# é, É, not in character set
# è, È, not in character set
# ë, Ë, not in character set
# ê, Ê, not in character set
# ï, Ï, not in character set
# î, Î, not in character set
# ô, Ô, not in character set
# ù, Ù, not in character set
# û, Û, not in character set
# ü, Ü, not in character set
# ÿ, Ÿ, not in character set
# set constraints
# Warning: variable name ":_to_B00" has a colon
# Warning: constraint name ":_mapped_once" has a colon
# Warning: to let Gurobi read it back, use rlp format
# optimizing with linear terms only...
# Optimize a model with 1536 rows, 15093 columns and 32066 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [4e-09, 1e+00]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+00]
# Found incumbent soln at node 0 objective 3.97877096787
# Found heuristic solution: objective 3.97877
# Presolve removed 1300 rows and 1990 columns
# Presolve time: 0.08s
# Presolved: 236 rows, 13103 columns, 26796 nonzeros
# Variable types: 0 continuous, 13103 integer (13103 binary)
#
# Root relaxation: objective 2.336078e+00, 1129 iterations, 0.06 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.33608    0   33    3.97877    2.33608  41.3%     -    0s
# Found incumbent soln at node 0 objective 2.33607744865
# H    0     0                       2.3360774    2.33608  0.00%     -    0s
#
# Explored 0 nodes (1133 simplex iterations) in 0.36 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.336077448653e+00, best bound 2.336077448653e+00, gap 0.0%
# done
# Performance: 2.336
# Association: 4.533
# Familiarity: 2.899
# Ergonomics: 3.192
# ! to E08
# # to C11
# $ to B04_Alt
# % to B00_Alt
# & to C01_Alt
# ( to E06
# ) to E05
# * to B09_Shift
# + to B10_Alt
# , to E00
# ,d to B09
# - to E01
# -d to B07
# . to E03
# .d to B08
# / to B00
# /d to C12
# : to B10
# ; to E02
# < to B08_Alt
# = to E07
# > to C11_Alt
# ? to E12_Shift
# @ to E12
# [ to E01_Alt
# \ to E11_Shift
# ] to D11_Shift
# ^d to D12
# _ to E10
# _d to C12_Shift
# { to D11
# | to C11_Shift
# } to B00_Shift
# ~d to C02_Alt
# ¡ to D11_Alt_Shift
# ¢ to C02_Alt_Shift
# £ to E05_Alt
# ¤ to C06_Alt_Shift
# ¥ to C03_Alt_Shift
# § to D11_Alt
# ¨d to B01_Alt
# © to D08_Alt
# ª to E03_Alt_Shift
# « to B08_Shift
# ® to D02_Alt
# ° to C03_Alt
# °d to E11_Alt
# ± to C05_Alt
# ´d to E03_Alt
# · to E07_Alt
# ¸d to B03_Alt
# º to E05_Alt_Shift
# » to B10_Shift
# ¼ to B08_Alt_Shift
# ½ to D05_Alt
# ¾ to B01_Alt_Shift
# ¿ to B02_Alt_Shift
# Æ to D04_Alt_Shift
# Ð to E06_Alt_Shift
# × to D09_Alt
# Þ to E10_Alt_Shift
# ß to C10_Alt
# à to E11
# æ to D04_Alt
# ç to D06_Alt
# è to E09
# é to E04
# ð to E06_Alt
# ÷ to E09_Alt_Shift
# ù to B09_Alt
# þ to E10_Alt
# İ to E12_Alt_Shift
# ı to E12_Alt
# Ĳ to C07_Alt_Shift
# ĳ to C07_Alt
# Ŋ to E02_Alt_Shift
# ŋ to E02_Alt
# Œ to E08_Alt_Shift
# œ to E08_Alt
# ſ to B09_Alt_Shift
# Ə to C09_Alt_Shift
# Ʒ to B05_Alt_Shift
# ə to C09_Alt
# ʒ to B05_Alt
# ˇd to D07_Alt
# ˉd to E04_Alt
# ˋd to E00_Shift
# ˘d to D09_Alt_Shift
# ˙d to D10_Alt
# ˛d to B02_Alt
# ˝d to E04_Alt_Shift
# ˵d to D08_Alt_Shift
# ̑d to D10_Alt_Shift
# θ2 to C05_Alt_Shift
# ẞ to C10_Alt_Shift
# ‑ to B07_Alt
# – to D12_Shift
# — to B07_Shift
# ‘ to C08_Alt
# ’ to C06_Alt
# ‚ to E07_Alt_Shift
# “ to E09_Alt
# ” to E00_Alt
# „ to D12_Alt
# † to C04_Alt
# ‡ to B06_Alt_Shift
# … to D01_Alt
# ‰ to B06_Alt
# ‹ to B03_Alt_Shift
# › to C12_Alt
# ₩ to C04_Alt_Shift
# √ to B07_Alt_Shift
# ∞ to B04_Alt_Shift
# ≃ to C08_Alt_Shift
# ≠ to B10_Alt_Shift
# ≤ to C01_Alt_Shift
# ≥ to B00_Alt_Shift
# Obj: 2.33608
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# ·: 0.444445
# @: 0.314277
# ß: 0.253268
# ç: 0.119552
# ₩: 0.004091
# #: 0.028235
# √: 0.094883
# ı: 0.147987
# à: 0.522863
# è: 0.593208
# ð: 0.076764
# ¥: 0.007768
# ©: 0.146998
# é: 0.188288
# ù: 0.127499
# ʒ: 0.003549
# ~d: 0.168211
# ¢: 0.026244
# ª: 0.136357
# ®: 0.075908
# ĳ: 0.088791
# º: 0.200797
# ŋ: 0.168096
# œ: 0.080406
# æ: 0.136359
'-': u'E01', u'\xae': u'D02_Alt', u'\u0133': u'C07_Alt', u'\u02dbd': u'B02_Alt', u'\u2039': u'B03_Alt_Shift', u'\xba': u'E05_Alt_Shift', u'=': u'E07', u'\xbe': u'B01_Alt_Shift', u'\u2021': u'B06_Alt_Shift', u'\xc6': u'D04_Alt_Shift', u'\u014b': u'E02_Alt', u'\u0153': u'E08_Alt', u'\u0259': u'C09_Alt', u']': u'D11_Shift', u'\xde': u'E10_Alt_Shift', u',d': u'B09', u'\u2265': u'B00_Alt_Shift', u'\xe6': u'D04_Alt', u'^d': u'D12', u'\u02f5d': u'D08_Alt_Shift', u'}': u'B00_Shift', u'\u017f': u'B09_Alt_Shift', u'\xfe': u'E10_Alt'}
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# set objective
# set constraints
# Warning: variable name ":_to_B00" has a colon
# Warning: constraint name ":_mapped_once" has a colon
# Warning: to let Gurobi read it back, use rlp format
# optimizing with linear terms only...
# Optimize a model with 246 rows, 15093 columns and 30186 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [1e-09, 9e-01]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+00]
# Found incumbent soln at node 0 objective 3.79357235742
# Found heuristic solution: objective 3.79357
# Presolve time: 0.04s
# Presolved: 246 rows, 15093 columns, 30186 nonzeros
# Variable types: 0 continuous, 15093 integer (15093 binary)
#
# Root relaxation: objective 1.403889e+00, 904 iterations, 0.04 seconds
# Found incumbent soln at node 0 objective 1.40388883045
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.4038888    1.40389  0.00%     -    0s
#
# Explored 0 nodes (904 simplex iterations) in 0.22 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.403888830445e+00, best bound 1.403888830445e+00, gap 0.0%
# done
# Performance: 2.844
# Association: 0.431
# Familiarity: 0.574
# Ergonomics: 1.767
# ! to B10
# # to C03_Alt
# $ to D12_Shift
# % to C11
# & to E02
# ( to E05
# ) to E10
# * to C12
# + to D11
# , to B07
# ,d to B10_Shift
# - to E06
# -d to E09
# . to B08
# .d to B07_Shift
# / to B09_Shift
# /d to E07
# : to B09
# ; to B08_Shift
# < to B00
# = to D12
# > to B00_Shift
# ? to B07_Alt
# @ to D02_Alt
# [ to D06_Alt
# \ to E08_Alt
# ] to C10_Alt
# ^d to D10_Alt
# _ to E08
# _d to E04
# { to D05_Alt
# | to B08_Alt
# } to D12_Alt
# ~d to B06_Alt
# ¡ to E00_Alt_Shift
# ¢ to B04_Alt_Shift
# £ to D11_Alt
# ¤ to D03_Alt_Shift
# ¥ to D06_Alt_Shift
# § to C11_Shift
# ¨d to D11_Shift
# © to B03_Alt_Shift
# ª to D01_Alt_Shift
# « to C08_Alt
# ® to D04_Alt_Shift
# ° to C07_Alt
# °d to C05_Alt
# ± to D12_Alt_Shift
# ´d to C01_Alt
# · to B07_Alt_Shift
# ¸d to B02_Alt
# º to D09_Alt_Shift
# » to B10_Alt
# ¼ to E03_Alt_Shift
# ½ to B10_Alt_Shift
# ¾ to D10_Alt_Shift
# ¿ to B08_Alt_Shift
# Æ to E11_Shift
# Ð to C12_Alt_Shift
# × to E02_Alt
# Þ to E12_Alt
# ß to C02_Alt
# à to E01
# æ to D01_Alt
# ç to B03_Alt
# è to D04_Alt
# é to E03
# ð to C03_Alt_Shift
# ÷ to E12_Alt_Shift
# ù to D07_Alt
# þ to D05_Alt_Shift
# İ to C05_Alt_Shift
# ı to D08_Alt
# Ĳ to E12
# ĳ to D08_Alt_Shift
# Ŋ to E00
# ŋ to B06_Alt_Shift
# Œ to C09_Alt_Shift
# œ to D09_Alt
# ſ to C02_Alt_Shift
# Ə to E01_Alt_Shift
# Ʒ to E11_Alt_Shift
# ə to C08_Alt_Shift
# ʒ to C07_Alt_Shift
# ˇd to C09_Alt
# ˉd to B09_Alt
# ˋd to B05_Alt
# ˘d to E03_Alt
# ˙d to B00_Alt
# ˛d to C11_Alt
# ˝d to D02_Alt_Shift
# ˵d to E05_Alt_Shift
# ̑d to C01_Alt_Shift
# θ2 to B05_Alt_Shift
# ẞ to E08_Alt_Shift
# ‑ to E04_Alt
# – to B04_Alt
# — to C04_Alt
# ‘ to E10_Alt
# ’ to C06_Alt
# ‚ to C12_Alt
# “ to E09_Alt
# ” to E01_Alt
# „ to E05_Alt
# † to E07_Alt
# ‡ to E09_Alt_Shift
# … to B01_Alt
# ‰ to E06_Alt
# ‹ to C10_Alt_Shift
# › to C12_Shift
# ₩ to B01_Alt_Shift
# √ to E04_Alt_Shift
# ∞ to D11_Alt_Shift
# ≃ to B02_Alt_Shift
# ≠ to E12_Shift
# ≤ to B00_Alt_Shift
# ≥ to E11
# Obj: 1.40389
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# ·: 0.111112
# @: 0.026190
# ¸d: 0.018388
# #: 0.016941
# √: 0.018977
# à: 0.047533
# è: 0.084744
# é: 0.094145
# ¢: 0.013122
# linear Association: 0.4312
# quadratic Association: 0.0000
# {u'/d': u'E07', u'\u2014': u'C04_Alt', u'\u2018': u'E10_Alt', u'\u201c': u'E09_Alt', u'-d': u'E09', u'\xa3': u'D11_Alt', u'$': u'D12_Shift', u'\xa7': u'C11_Shift', u'(': u'E05', u'\xab': u'C08_Alt', u',': u'B07', u'\u2030': u'E06_Alt', u'\u0132': u'E12', u'\xb7': u'B07_Alt_Shift', u'\xbb': u'B10_Alt', u'_d': u'E04', u'<': u'B00', u'\xbf': u'B08_Alt_Shift', u'@': u'D02_Alt', u'\u014a': u'E00', u'\xb8d': u'B02_Alt', u'\u0152': u'C09_Alt_Shift', u'\xd7': u'E02_Alt', u'\\': u'E08_Alt', u'\xdf': u'C02_Alt', u'\u2264': u'B00_Alt_Shift', u'\u2260': u'E12_Shift', u'\u02ddd': u'D02_Alt_Shift', u'\xe7': u'B03_Alt', u'\xf7': u'E12_Alt_Shift', u'\u02c9d': u'B09
# è, È, not in character set
# ë, Ë, not in character set
# ê, Ê, not in character set
# ï, Ï, not in character set
# î, Î, not in character set
# ô, Ô, not in character set
# ù, Ù, not in character set
# û, Û, not in character set
# ü, Ü, not in character set
# ÿ, Ÿ, not in character set
# set constraints
# Warning: variable name ":_to_B00" has a colon
# Warning: constraint name ":_mapped_once" has a colon
# Warning: to let Gurobi read it back, use rlp format
# optimizing with linear terms only...
# Optimize a model with 1536 rows, 15093 columns and 32066 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [1e-09, 9e-01]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+00]
# Found incumbent soln at node 0 objective 3.96919041248
# Found heuristic solution: objective 3.96919
# Presolve removed 1300 rows and 1990 columns
# Presolve time: 0.08s
# Presolved: 236 rows, 13103 columns, 26796 nonzeros
# Variable types: 0 continuous, 13103 integer (13103 binary)
#
# Root relaxation: objective 1.431237e+00, 843 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.43124    0   30    3.96919    1.43124  63.9%     -    0s
# Found incumbent soln at node 0 objective 1.45989591843
# H    0     0                       1.4598959    1.43124  1.96%     -    0s
# Found incumbent soln at node 0 objective 1.44356433317
# H    0     0                       1.4435643    1.43124  0.85%     -    0s
# Found incumbent soln at node 0 objective 1.44323349779
# H    0     0                       1.4432335    1.43124  0.83%     -    0s
# Found incumbent soln at node 0 objective 1.44018997084
# *    0     0               0       1.4401900    1.44019  0.00%     -    0s
#
# Cutting planes:
#   Clique: 3
#   Mod-K: 3
#
# Explored 0 nodes (863 simplex iterations) in 0.71 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.440189970836e+00, best bound 1.440189970836e+00, gap 0.0%
# done
# Performance: 2.834
# Association: 0.577
# Familiarity: 0.586
# Ergonomics: 1.765
# ! to B10
# # to D02_Alt
# $ to D12_Shift
# % to C11
# & to E02
# ( to E05
# ) to E10
# * to C12
# + to D11
# , to B07
# ,d to B10_Shift
# - to E06
# -d to E07
# . to B08
# .d to B07_Shift
# / to B09_Shift
# /d to E09
# : to B09
# ; to B08_Shift
# < to B00
# = to D12
# > to B00_Shift
# ? to B07_Alt
# @ to D01_Alt
# [ to D06_Alt
# \ to E08_Alt
# ] to C10_Alt
# ^d to D10_Alt
# _ to E08
# _d to E04
# { to C04_Alt
# | to B09_Alt
# } to D12_Alt
# ~d to B06_Alt
# ¡ to B06_Alt_Shift
# ¢ to B02_Alt_Shift
# £ to E12_Shift
# ¤ to E12_Alt
# ¥ to D06_Alt_Shift
# § to B10_Alt_Shift
# ¨d to D09_Alt
# © to B03_Alt_Shift
# ª to D01_Alt_Shift
# « to B08_Alt
# ® to D04_Alt_Shift
# ° to E10_Alt
# °d to C11_Shift
# ± to B08_Alt_Shift
# ´d to C01_Alt
# · to B04_Alt_Shift
# ¸d to B02_Alt
# º to D09_Alt_Shift
# » to B10_Alt
# ¼ to E12_Alt_Shift
# ½ to E11
# ¾ to E08_Alt_Shift
# ¿ to E11_Shift
# Æ to E01_Alt_Shift
# Ð to C03_Alt_Shift
# × to E05_Alt
# Þ to D05_Alt_Shift
# ß to C02_Alt
# à to E01
# æ to E01_Alt
# ç to B03_Alt
# è to D04_Alt
# é to E03
# ð to C03_Alt
# ÷ to E04_Alt_Shift
# ù to D07_Alt
# þ to D05_Alt
# İ to C08_Alt_Shift
# ı to C08_Alt
# Ĳ to D08_Alt_Shift
# ĳ to D08_Alt
# Ŋ to B05_Alt_Shift
# ŋ to B05_Alt
# Œ to C09_Alt_Shift
# œ to C09_Alt
# ſ to C01_Alt_Shift
# Ə to E00_Shift
# Ʒ to C07_Alt_Shift
# ə to E00
# ʒ to C07_Alt
# ˇd to D11_Shift
# ˉd to E04_Alt
# ˋd to C12_Shift
# ˘d to E03_Alt
# ˙d to C11_Alt
# ˛d to E02_Alt
# ˝d to D10_Alt_Shift
# ˵d to E06_Alt_Shift
# ̑d to C06_Alt_Shift
# θ2 to C10_Alt_Shift
# ẞ to C02_Alt_Shift
# ‑ to E07_Alt
# – to B04_Alt
# — to C05_Alt
# ‘ to D11_Alt
# ’ to C06_Alt
# ‚ to E12
# “ to E09_Alt
# ” to B00_Alt
# „ to C04_Alt_Shift
# † to E06_Alt
# ‡ to E11_Alt_Shift
# … to B01_Alt
# ‰ to C05_Alt_Shift
# ‹ to E07_Alt_Shift
# › to C12_Alt
# ₩ to B01_Alt_Shift
# √ to D03_Alt_Shift
# ∞ to D02_Alt_Shift
# ≃ to E11_Alt
# ≠ to B00_Alt_Shift
# ≤ to B09_Alt_Shift
# ≥ to C11_Alt_Shift
# Obj: 1.44019
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# ·: 0.111112
# ¸d: 0.018388
# #: 0.028235
# √: 0.018977
# ı: 0.029597
# à: 0.047533
# è: 0.084744
# é: 0.094145
# ¢: 0.013122
# ŋ: 0.024014
# œ: 0.040203
# æ: 0.045453
# ſ: 0.021106
# linear Association: 0.5766
# quadratic Association: 0.0000
# {u'/d': u'E09', u'\u2014': u'C05_Alt', u'\u2018': u'D11_Alt', u'\u201c': u'E09_Alt', u'-d': u'E07', u'\xa3': u'E12_Shift', u'$': u'D12_Shift', u'\xa7': u'B10_Alt_Shift', u'(': u'E05', u'\xab': u'B08_Alt', u',': u'B07', u'\u2030': u'C05_Alt_Shift', u'\u0132': u'D08_Alt_Shift', u'\xb7': u'B04_Alt_Shift', u'\xbb': u'B10_Alt', u'_d': u'E04', u'<': u'B00', u'\xbf': u'E11_Shift', u'@': u'D01_Alt', u'\u014a': u'B05_Alt_Shift', u'\xb8d': u'B02_Alt', u'\u0152': u'C09_Alt_Shift', u'\xd7': u'E05_Alt', u'\\': u'E08_Alt', u'\xdf': u'C02_Alt', u'\u2264': u'B09_Alt_Shift', u'\u2260': u'B00_Alt_Shift', u'\u02ddd': u'D10_Alt_Shift', u'\xe7': u'B03_Alt', u'\xf7': u'E04_Alt_Shift', u'\u02c9d': u'E04_Alt', u
# weighting corpora
# weighting corpora
# Done reading input values.
# ·: 0.111112
# ¸d: 0.073486
# ǝ: 0.499931
# ç: 0.023911
# #: 0.028235
# ı: 0.029597
# à: 0.047533
# è: 0.084744
# ¥: 0.013594
# é: 0.094145
# º: 0.040160
# ŋ: 0.024014
# æ: 0.045453
# ſ: 0.021106
# linear Association: 1.1370
# (, {: 0.067291
# ., ·: 0.157724
# !, ¡: 0.066535
# -, -d: 0.052487
# ½, ¾: 0.000001
# ÷, ×: 0.000011
# ˘d, ˇd: 0.000203
# (, ): 0.144486
# ,, ;: 0.098158
# (, [: 0.060863
# *, ×: 0.011863
# =, ≃: 0.059696
# =, ≠: 0.017056
# ˝d, ˵d: 0.000010
# «, »: 0.011937
# ,, ,d: 0.104902
# †, ‡: 0.000026
# ´d, é: 0.164055
# /, ÷: 0.384544
# ;, :: 0.083885
# [, {: 0.043962
# <, >: 0.021540
# %, ‰: 0.019657
# ¸d, ç: 0.004408
# ½, ¼: 0.000001
# ǝ, Ǝ: 0.000018
# ?, ¿: 0.017643
# -, +: 0.177724
# ˉd, _d: 0.000024
# /, \: 0.484524
# ˋd, è: 0.029005
# _, _d: 0.011302
# ;, .: 0.066667
# ], }: 0.029587
# ·, ×: 0.000055
# >, ≥: 0.004520
# ˋd, ù: 0.001346
# -, ‑: 0.052498
# {, }: 0.028407
# [, ]: 0.036784
# ¨d, ^d: 0.019966
# ˘d, ̑d: 0.000050
# ), }: 0.046320
# ´d, ˋd: 0.000229
# ‚, „: 0.000003
# İ, ı: 0.000004
# ±, =: 0.025589
# ¸d, ˛d: 0.000049
# -, —: 0.142085
# ˙d, .d: 0.000031
# “, ”: 0.000379
# ‘, ’: 0.009603
# ˋd, à: 0.042274
# <, ≤: 0.013305
# -, –: 0.070523
# ≤, ≥: 0.000002
# ), ]: 0.126533
# ¼, ¾: 0.000000
# ^d, ˋd: 0.037805
# ‹, ›: 0.000039
# quadratic Association: 3.0502

# %%
azerty,\
    characters,\
    keyslots,\
    letters,\
    p_single, p_bigram,\
    performance,\
    similarity_c_c, similarity_c_l,\
    distance_level_0, distance_level_1,\
    ergonomics\
     = get_all_input_values(corpus_weights)
        
linear_cost, x_P, x_A, x_F, x_E = get_linear_costs(w_p, w_a, w_f, w_e, 
                           azerty,\
                           characters,\
                           keyslots,\
                           letters,\
                           p_single, p_bigram,\
                           performance,\
                           similarity_c_c, similarity_c_l,\
                           distance_level_0, distance_level_1,\
                           ergonomics)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.

# %%
c=u'à'
l=u'a'
s1 = u'E01'
s2 = u'D01_Alt'
x_A[(c, s1)]
# Out:
# 0.035650064642712094

# %%
2*((p_single[c] + p_single[l])*similarity_c_l[(c,l)]*distance_level_0[s2,azerty[l]])
# Out:
# 0.011456665704620669

# %%
distance_level_0[s1,azerty[l]]
# Out:
# 0.055556

# %%
linear_cost[c,s2]
# Out:
# 0.071299487589394181
