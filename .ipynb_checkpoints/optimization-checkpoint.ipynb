# %%
from objectives import * 
from read_input import *
from plotting import *
from reformulation_input import *
from evaluate_reformualtion_solution import * 
from optimize import *

# %matplotlib inline

PYTHONIOENCODING="utf-8"

w_p, w_a, w_f, w_e =  [0.25,0.25,0.25,0.25]
corpus_weights = {'formal':0.5, 'twitter':0.3, 'code':0.2}
# Out:
# C:\Users\feita1\Python_Anaconda\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
scenario = "scenarioMAX"
char_set = "setCAPS"
set_scenario_files(scenario, char_set)
#create_reformulation_input(w_p, w_a, w_f, w_e, corpus_weights, scenario+char_set+"_even",
                           #quadratic=1)

mapping = solve_the_keyboard_Problem(w_p, w_a, w_f, w_e, corpus_weights, 
                                     quadratic=1, capitalization_constraints=1, name=scenario+char_set+"_even", minimize=True)
#model = optimize_reformulation("reformulation\\reformulation_scenario3_ass.lp")
#w_p, w_a, w_f, w_e = [0.25,0.25,0.25,0.25]
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# Getting linear cost
# set objective
# Adding capitalization constraints
# à, À, not in character set
# â, Â, not in character set
# ç, Ç, not in character set
# é, É, not in character set
# è, È, not in character set
# ë, Ë, not in character set
# ê, Ê, not in character set
# ï, Ï, not in character set
# î, Î, not in character set
# ô, Ô, not in character set
# ù, Ù, not in character set
# û, Û, not in character set
# ü, Ü, not in character set
# ÿ, Ÿ, not in character set
# set constraints
# Warning: variable name ":_to_B00" has a colon
# Warning: constraint name ":_mapped_once" has a colon
# Warning: to let Gurobi read it back, use rlp format
# optimizing with linear terms only...
# Optimize a model with 1540 rows, 15609 columns and 33098 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e-11, 1e-02]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e+00, 1e+00]
# Found incumbent soln at node 0 objective 0.0267850220733
# Found heuristic solution: objective 0.026785
# Presolve removed 1300 rows and 1990 columns
# Presolve time: 0.25s
# Presolved: 240 rows, 13619 columns, 27828 nonzeros
# Variable types: 0 continuous, 13619 integer (13619 binary)
#
# Root relaxation: objective 5.929969e-02, 702 iterations, 0.14 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.05930    0   24    0.02679    0.05930   121%     -    0s
# Found incumbent soln at node 0 objective 0.0592996993905
# H    0     0                       0.0592997    0.05930  0.00%     -    1s
#
# Explored 0 nodes (972 simplex iterations) in 1.02 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.929969939048e-02, best bound 5.929969939048e-02, gap 0.0%
# done
# Performance: 0.496
# Association: 0.566
# Familiarity: 0.488
# Ergonomics: 0.059
# ! to B00_Alt_Shift
# " to E11_Alt
# # to E04_Alt_Shift
# $ to D12_Alt
# % to D02_Alt_Shift
# & to E05_Alt
# ' to E00_Shift
# ( to D12_Alt_Shift
# ) to C11_Alt_Shift
# * to C03_Alt_Shift
# + to E01_Alt_Shift
# , to E11_Alt_Shift
# ,d to B06_Alt
# - to E06_Alt_Shift
# -d to D02_Alt
# . to E12_Alt_Shift
# .d to B00_Shift
# / to E12_Shift
# /d to C07_Alt
# : to C12_Alt_Shift
# ; to E10_Alt_Shift
# < to E09_Alt
# = to D11_Alt_Shift
# > to B07_Alt_Shift
# ? to E08_Alt
# @ to E08_Alt_Shift
# [ to E12_Alt
# \ to E12
# ] to B04_Alt_Shift
# ^ to C02_Alt_Shift
# ^d to E05_Alt_Shift
# _ to E09_Alt_Shift
# _d to C06_Alt
# { to E07_Alt_Shift
# | to E01_Alt
# } to E03_Alt_Shift
# ~ to B03_Alt_Shift
# ~d to D06_Alt_Shift
# ¡ to E04
# ¢ to B02_Alt
# £ to E00
# ¤ to E03
# ¥ to D06_Alt
# § to C04_Alt
# ¨d to E06_Alt
# © to D12_Shift
# ª to E09
# « to D07_Alt_Shift
# ® to C08_Alt_Shift
# ° to D04_Alt_Shift
# °d to B01_Alt
# ± to B05_Alt_Shift
# ´d to B09_Alt_Shift
# · to B06_Alt_Shift
# ¸d to E07_Alt
# º to C01_Alt_Shift
# » to C11_Alt
# ¼ to B08_Shift
# ½ to D08_Alt_Shift
# ¾ to B00
# ¿ to E10
# Æ to C12_Shift
# Ð to D10_Alt_Shift
# × to C05_Alt
# Þ to C11_Shift
# ß to D09_Alt
# à to E11_Shift
# æ to C12
# ç to E03_Alt
# è to E00_Alt
# é to E00_Alt_Shift
# ð to D10_Alt
# ÷ to C03_Alt
# ù to E02_Alt
# þ to C11
# İ to C10_Alt_Shift
# ı to C10_Alt
# Ĳ to B10_Shift
# ĳ to B10
# Ŋ to C09_Alt_Shift
# ŋ to C09_Alt
# Œ to B08_Alt_Shift
# œ to B08_Alt
# ſ to C08_Alt
# Ə to D11_Shift
# Ʒ to B09_Shift
# ə to D11
# ʒ to B09
# ˇd to C12_Alt
# ˉd to D05_Alt_Shift
# ˋd to D01_Alt_Shift
# ˘d to D08_Alt
# ˙d to D11_Alt
# ˛d to E05
# ˝d to D03_Alt_Shift
# ˵d to B03_Alt
# ̑d to B07_Alt
# θ2 to B10_Alt
# ẞ to D09_Alt_Shift
# ‑ to C05_Alt_Shift
# – to C06_Alt_Shift
# — to E10_Alt
# ‘ to C01_Alt
# ’ to E02_Alt_Shift
# ‚ to B07_Shift
# “ to C07_Alt_Shift
# ” to B10_Alt_Shift
# „ to E11
# † to B09_Alt
# ‡ to B01_Alt_Shift
# … to E04_Alt
# ‰ to D07_Alt
# ‹ to E06
# › to B02_Alt_Shift
# ₩ to B07
# √ to D01_Alt
# ∞ to D05_Alt
# ≃ to B00_Alt
# ≠ to E02
# ≤ to B08
# ≥ to C04_Alt_Shift
# Obj: 0.0592997
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# Getting linear cost
# linear Association: 0.5660
# quadratic Association: 0.0000

# %%
path = "mappings/solution_3_even.mst"
plot_mapping(mapping, plotname=path+".png", w_p=w_p, w_a=w_a, w_f=w_f, w_e=w_e,  
             corpus_weights=corpus_weights, quadratic=1)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
# Getting linear cost
# linear Association: 0.5660
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-44bb007e6bab> in <module>()
#       1 path = "mappings/solution_3_even.mst"
#       2 plot_mapping(mapping, plotname=path+".png", w_p=w_p, w_a=w_a, w_f=w_f, w_e=w_e,
# ----> 3              corpus_weights=corpus_weights, quadratic=1)
#
# C:\LocalUserData\User-data\feita1\Uni\PhD\Projects\French keyboard\Optimization\optimizing-the-french-keyboard\plotting.pyc in plot_mapping(mapping, plotname, azerty, numbers, letters, corpus_weights, quadratic, objective, p, a, f, e, w_p, w_a, w_f, w_e)
#     154
#     155     if objective==-1:
# --> 156             objective, p, a, f, e = get_objectives(mapping, w_p, w_a, w_f, w_e, corpus_weights, quadratic=quadratic)
#     157
#     158     if azerty == -1:
#
# C:\LocalUserData\User-data\feita1\Uni\PhD\Projects\French keyboard\Optimization\optimizing-the-french-keyboard\objectives.pyc in get_objectives(mapping, w_p, w_a, w_f, w_e, corpus_weights, quadratic)
#      29                                similarity_c_c, similarity_c_l,\
#      30                                distance_level_0, distance_level_1,\
# ---> 31                                ergonomics, quadratic=quadratic)
#      32
#      33 def accu_get_objectives(mapping, w_p, w_a, w_f, w_e,\
#
# C:\LocalUserData\User-data\feita1\Uni\PhD\Projects\French keyboard\Optimization\optimizing-the-french-keyboard\objectives.pyc in accu_get_objectives(mapping, w_p, w_a, w_f, w_e, azerty, characters, keyslots, letters, p_single, p_bigram, performance, similarity_c_c, similarity_c_l, distance_level_0, distance_level_1, ergonomics, quadratic)
#      80     print 'linear Association: %.4f'%lin_A
#      81     if quadratic:
# ---> 82         prob_sim, distance_level_0_norm = get_quadratic_cost(characters,\
#      83                                keyslots,\
#      84                                p_single,distance_level_0,\
#
# NameError: global name 'get_quadratic_cost' is not defined

# %%
new_mapping = swap_and_plot(mapping, u"à", u":",corpus_weights, w_p, w_a, w_f, w_e,  plot=True)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.

# %%
azerty,\
    characters,\
    keyslots,\
    letters,\
    p_single, p_bigram,\
    performance,\
    similarity_c_c, similarity_c_l,\
    distance_level_0, distance_level_1,\
    ergonomics\
     = get_all_input_values(corpus_weights)
        
linear_cost, x_P, x_A, x_F, x_E = get_linear_costs(w_p, w_a, w_f, w_e, 
                           azerty,\
                           characters,\
                           keyslots,\
                           letters,\
                           p_single, p_bigram,\
                           performance,\
                           similarity_c_c, similarity_c_l,\
                           distance_level_0, distance_level_1,\
                           ergonomics)
# Out:
# read in: characters, keyslots and letters
# read in: similarity values
# read in: distance values
# weighting corpora
# weighting corpora
# weighting corpora
# Done reading input values.
